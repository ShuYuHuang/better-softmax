# %%
# !pip install plotly

# %%
# !pip uninstall -y numpy
# !pip install numpy
# Out:
# Found existing installation: numpy 1.16.6
# Uninstalling numpy-1.16.6:
#   Successfully uninstalled numpy-1.16.6
# Collecting numpy
#   Downloading numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 1.7 MB/s eta 0:00:01
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorlayer 2.1.0 requires numpy<1.17,>=1.16, but you have numpy 1.21.4 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.21.4 which is incompatible.
# tensorflow 2.4.1 requires wrapt~=1.12.1, but you have wrapt 1.11.1 which is incompatible.
# Successfully installed numpy-1.21.4

# %%
import numpy as np
import pandas as pd
import math
import time
from functools import partial

import plotly.express as px

import tensorflow as tf
import tensorflow.keras as keras

from sklearn.model_selection import train_test_split

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
np.random.seed(2021)
tf.random.set_seed(2021)

# %%
num_classes=10

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train_1hot = keras.utils.to_categorical(y_train, num_classes)
y_test_1hot = keras.utils.to_categorical(y_test, num_classes)

# %%
batch_size = 128
meta_batch_size = 32
epochs = 10
plt_x,plt_y=x_test[:batch_size],y_test[:batch_size]

# %%
train_loader = tf.data.Dataset.from_tensor_slices((x_train,y_train))
all_class_list=[train_loader.filter(lambda x,y: y==yy)
                  .cache()
                  .shuffle(2000)
                  .prefetch(50)
                 for yy in range(num_classes)]

# %%
WAYS=2
SHOTS=1
W,H,CH=28,28,1

# %%
for ii in all_class_list[1]:
    break
# px.imshow(ii[0][...,0])

# %%
def form_meta(dataset_list,mult=4):
    orders=np.concatenate([np.random.permutation(len(dataset_list)) for x in range(mult)])
    for tasks in range(len(orders)//WAYS):
        picked=[dataset_list[tt] for tt in orders[WAYS*tasks:WAYS*(tasks+1)]]
        # 選一個人當 support'''
        idx_s=np.random.choice(range(WAYS), size=1, replace=False)
        # 選1張照片當 query'''
        idx_q=np.random.choice(range(WAYS), size=1, replace=False)
        if idx_q[0]==idx_s[0]:
            tmp=next(iter(picked[idx_s[0]].batch(2)))[0]
            support=tmp[-1]
            query=tmp[0]
        else:
            support=next(iter(picked[idx_s[0]]))[0]
            query=next(iter(picked[idx_q[0]]))[0]
        x=tf.stack((support,query), axis=0)
        # 如果該query照片跟support同種就是1，不同就是0'''
        y=tf.constant(idx_s==idx_q,dtype=tf.float32)
        yield x, y

# def form_meta2(dataset):

# %%
MULT=40
train_meta_loader=tf.data.Dataset.from_generator(partial(form_meta,all_class_list,MULT),
                                                 output_types=(tf.float32,tf.float32),
                                                output_shapes=((2,W,H,CH),1))

# %%
start_time=time.time()
for ld in all_class_list:
    for xx,yy in ld.batch(500):
        pass
print(f"{time.time()-start_time:.03f} sec")
# Out:
# 14.635 sec

# %%
start_time=time.time()
for ld in all_class_list:
    for xx,yy in ld.batch(500):
        pass
print(f"{time.time()-start_time:.03f} sec")
# Out:
# 2.893 sec

# %%
## Embedding ##
class Encoder(keras.Model):
    def __init__(self,n_layers=2,latent_features=2,hidden_featrues=64):
        super().__init__()
        self.latent_features=latent_features
        # First Layer
        self.conv_0=keras.layers.Conv2D(hidden_featrues, kernel_size=3, activation="relu",padding='same')
        self.dropout_0=keras.layers.Dropout(0.2)
        # Middle Layers
        self.convs=[keras.layers.Conv2D(hidden_featrues, kernel_size=3, activation="relu",padding='same') for _ in range(n_layers)]
        self.mxpools = [keras.layers.MaxPooling2D(pool_size=2) for _ in range(n_layers)]
        self.dropouts = [keras.layers.Dropout(0.2) for _ in range(n_layers)]
        # Integration Layer(Output Layer)
        WIDTH=2
        self.gap=keras.layers.AveragePooling2D(pool_size=WIDTH,)
        self.flatten=keras.layers.Flatten()
        self.dense=keras.layers.Dense(latent_features)
      
    def call(self,x):
        x=self.dropout_0(self.conv_0(x))
        for conv,mxp,drp in zip(self.convs,self.mxpools,self.dropouts):
            x=drp(mxp(conv(x)))
        x=self.gap(x)
        x=self.flatten(x)
        y=self.dense(x)
        return y

## Special Layers ##

def EuclideanDist(q,s):
    return tf.math.reduce_euclidean_norm(q-s,axis=-1,keepdims=True)

def MatMul(q,s):
    return tf.reduce_sum(tf.multiply(q,s),axis=-1,keepdims=True)

class CosSim:
    def __init__(self,mode="paired"):
        self.mode=mode
        assert mode in ["paired","matmult"]
    def __call__(self,q,s):
        query_n=tf.math.l2_normalize(q, axis=-1)
        support_n=tf.math.l2_normalize(s, axis=-1)
        if self.mode=="paired":
            cosine=MatMul(query_n,support_n)
        if self.mode=="matmult":
            cosine=tf.matmul(query_n,support_n,transpose_b=True)
        return cosine
    
class CosineLayer(keras.layers.Layer):
    def __init__(self, out_features=10,mode="matmult"):
        super().__init__()
        self.out_features = out_features
        self.cos_sim=CosSim(mode)
    def build(self, input_shape):
        self.w = self.add_weight(shape=(self.out_features,input_shape[-1]),
                               initializer='glorot_uniform',
                               trainable=True)
    def call(self, inputs):
        return self.cos_sim(inputs,self.w)

## Loss function ##
class ContrastiveLoss:
    def __init__(self,m=1,mode="dist"):
        
        self.mode=mode
        if self.mode=="dist":
            self.m=m
        if self.mode=="cos" or self.mode=="matmul":
            self.activation=keras.activations.sigmoid
            self.loss_fn=keras.losses.BinaryCrossentropy()
        assert mode in ["dist","cos","matmul"]
        self.__name__="loss"
    def __call__(self,y_true, y_pred):
        if self.mode=="dist":
            loss=tf.reduce_mean(y_true * tf.square(y_pred) +
                                 (1 - y_true)* tf.square(tf.maximum(self.m - y_pred, 0)),
                               axis=-1,keepdims=True)
        if self.mode=="cos" or self.mode=="matmul":
            loss=self.loss_fn(y_true,self.activation(y_pred))
        return loss


class FocalLoss:
    def __init__(self, gamma=3, eps=1e-10):
        self.gamma = gamma
        self.eps = tf.constant(eps)
        self.softmax =keras.layers.Softmax()
        self.cce=keras.losses.CategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
        self.__name__="loss"
    def __call__(self,y_true, y_pred): 
        logp = self.cce(y_true,self.softmax(y_pred+self.eps))
        p = tf.exp(-logp)
        loss = (tf.constant(1.) - p) ** self.gamma * logp
        return tf.reduce_mean(loss, axis=-1)
    
class AddMarginLoss():
    def __init__(self,s=5,m=0.3,gamma=3):
        self.s = s
        self.m = m
        self.lossfn=FocalLoss(gamma)
        self.__name__="loss"
    def __call__(self, y_true, y_pred):
        cosine=y_pred
        phi = cosine - self.m
        # -------------torch.where(out_i = {x_i if condition_i else y_i) -------------
        arc = (y_true * phi) + ((1.0 - y_true) * cosine)  # you can use torch.where if your torch.__version__ is 0.4
        arc *= self.s
        return self.lossfn(y_true,arc)
    
class ArcMarginLoss():
    def __init__(self,s=32,m=0.3,easy_margin=False,gamma=3, eps=1e-6):
        self.s = s
        self.m = m
        self.eps=tf.constant(eps)# This is very, very, very important
        self.easy_margin = easy_margin
        self.cos_m = math.cos(m)
        self.sin_m = math.sin(m)
        self.th = math.cos(math.pi - m)
        self.mm = math.sin(math.pi - m) * m
        
        self.lossfn=FocalLoss(gamma)
        self.__name__="loss"
    def __call__(self, y_true, y_pred):
        cosine=y_pred
        
        sine = tf.sqrt(tf.constant(1.) - tf.pow(cosine, 2) + self.eps)
        
        phi = cosine * self.cos_m - sine * self.sin_m
        if self.easy_margin:
            phi = tf.where(cosine > 0, phi, cosine)
        else:
            phi = tf.where((cosine - self.th) > 0, phi, cosine - self.mm)
        
        # -------------torch.where(out_i = {x_i if condition_i else y_i) -------------
        arc = (y_true * phi) + ((1.0 - y_true) * cosine)  # you can use torch.where if your torch.__version__ is 0.4
        arc *= self.s
        return self.lossfn(y_true,arc)
    
## Main Model ##
class ClassModel(keras.Model):
    def __init__(self,encoder,out_features=10,mode="dense"):
        super().__init__()
        self.encoder=encoder
        self.mode=mode
        self.latent_features=encoder.latent_features
        
        if self.mode=="dense":
            self.output_layer=keras.layers.Dense(out_features,use_bias=False)
            self.out_func=keras.layers.Softmax()
        else:
            self.output_layer=CosineLayer(out_features)
        assert mode in ["dist","cos","arc"]
        
    def call(self,x,training=False):
        latent=self.encoder(x)
        if self.mode=="dense":
            y=self.out_func(self.output_layer(latent))
            return y
        else:
            cosine=self.output_layer(latent)
            return cosine

class SiameseModel(keras.Model):
    # Mode: dist= euclidean distance
    #       cos = cosine distance
    #       matmult= matric multiplication distance
    def __init__(self,encoder,mode="cos"):
        super().__init__()
        assert mode in ["dist","cos","matmul"]
        self.encoder=encoder
        self.mode=mode
        self.latent_features=encoder.latent_features
        if self.mode=="dist":
            self.matric_fn=EuclideanDist
        if self.mode=="cos":
            self.matric_fn=CosSim("paired")
        if self.mode=="matmul":
            self.matric_fn=MatMul
        self.loss_fn=ContrastiveLoss(1,mode=mode)
       
            
    def call(self,x,training=False):
        latent_s=self.encoder(x[:,0])
        latent_q=self.encoder(x[:,1])

        return self.matric_fn(latent_q,latent_s)

# %%
enc=Encoder(n_layers=2,latent_features=2,hidden_featrues=64)
model=SiameseModel(enc,mode="dist")# {"dist","cos","matmul"}

# %%
# loss_fn=ArcMarginLoss(s=5,m=0.4,easy_margin=False)
loss_fn=model.loss_fn
opt=keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss=loss_fn, optimizer=opt, metrics=[keras.metrics.BinaryAccuracy(threshold=0.5)])

# %%
## Recording Callbacks
class LogLatent(keras.callbacks.Callback):
    def __init__(self,encoder,test_x,test_y,skip_iters=100):
        self.df=self.df=pd.DataFrame()
        self.encoder=encoder
        self.plt_x=test_x
        self.plt_y=test_y
        self.itr=0
        self.skip_iters=skip_iters
    def on_batch_end(self,batch, logs={}):
        if self.itr%self.skip_iters==self.skip_iters-1:
            latent=self.encoder(self.plt_x)
            df_new=pd.DataFrame()
            df_new["f1"]=latent[:,0]
            df_new["f2"]=latent[:,1]
            df_new["arc"]=0.5
            df_new["iterations"]=np.repeat(self.itr,len(latent))

            df_new["label"]=self.plt_y
            self.df=self.df.append(df_new)
        self.itr+=1
    def normalize(self):
        # Normalize latent by maximum value
        self.mx_norm=np.linalg.norm(self.df[["f1","f2"]].values,axis=1).max()
        self.df[["f1",'f2']]=self.df[["f1",'f2']].apply(lambda x: x/self.mx_norm)

        # Project latents into arc
        df=self.df.copy()
        norm=np.linalg.norm(df[["f1","f2"]].values,axis=1,keepdims=True)
        df[["f1",'f2']]=df[["f1",'f2']].values/norm
        df["arc"]=df["arc"].map({0.5:0.9},na_action=None)
        
        self.df=self.df.append(df)

# %%
train_loader = train_meta_loader.shuffle(1000).cache().prefetch(meta_batch_size).batch(meta_batch_size)

val_loader = train_meta_loader.shuffle(1000).cache().prefetch(meta_batch_size*4).batch(meta_batch_size*4)

# %%
lg=LogLatent(enc,plt_x,plt_y)
try:
    model.fit(train_loader, 
              epochs=800,
              validation_data=val_loader,
              callbacks=[lg])
except KeyboardInterrupt:
    print("KeyboardInterrupt")
# Out:
# Epoch 1/800
# 7/7 [==============================] - 1s 44ms/step - loss: 0.3409 - binary_accuracy: 0.4404 - val_loss: 0.2518 - val_binary_accuracy: 0.4200
# Epoch 2/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2336 - binary_accuracy: 0.3310 - val_loss: 0.2625 - val_binary_accuracy: 0.4100
# Epoch 3/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2034 - binary_accuracy: 0.3251 - val_loss: 0.2525 - val_binary_accuracy: 0.4000
# Epoch 4/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1863 - binary_accuracy: 0.2821 - val_loss: 0.2231 - val_binary_accuracy: 0.3700
# Epoch 5/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1670 - binary_accuracy: 0.2773 - val_loss: 0.2218 - val_binary_accuracy: 0.3900
# Epoch 6/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1619 - binary_accuracy: 0.2515 - val_loss: 0.2208 - val_binary_accuracy: 0.3800
# Epoch 7/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1506 - binary_accuracy: 0.1861 - val_loss: 0.2043 - val_binary_accuracy: 0.3100
# Epoch 8/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1371 - binary_accuracy: 0.1877 - val_loss: 0.1956 - val_binary_accuracy: 0.3000
# Epoch 9/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1307 - binary_accuracy: 0.1689 - val_loss: 0.1980 - val_binary_accuracy: 0.3100
# Epoch 10/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1468 - binary_accuracy: 0.1701 - val_loss: 0.2020 - val_binary_accuracy: 0.3150
# Epoch 11/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1228 - binary_accuracy: 0.1483 - val_loss: 0.1850 - val_binary_accuracy: 0.2650
# Epoch 12/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1127 - binary_accuracy: 0.1219 - val_loss: 0.1821 - val_binary_accuracy: 0.2750
# Epoch 13/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1146 - binary_accuracy: 0.1226 - val_loss: 0.1832 - val_binary_accuracy: 0.2650
# Epoch 14/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1028 - binary_accuracy: 0.0905 - val_loss: 0.1772 - val_binary_accuracy: 0.2850
# Epoch 15/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1110 - binary_accuracy: 0.0871 - val_loss: 0.1762 - val_binary_accuracy: 0.2750
# Epoch 16/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1061 - binary_accuracy: 0.1147 - val_loss: 0.1735 - val_binary_accuracy: 0.2750
# Epoch 17/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1021 - binary_accuracy: 0.0815 - val_loss: 0.1708 - val_binary_accuracy: 0.2700
# Epoch 18/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0975 - binary_accuracy: 0.1252 - val_loss: 0.1711 - val_binary_accuracy: 0.2550
# Epoch 19/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0940 - binary_accuracy: 0.1009 - val_loss: 0.1683 - val_binary_accuracy: 0.2500
# Epoch 20/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0825 - binary_accuracy: 0.0833 - val_loss: 0.1671 - val_binary_accuracy: 0.2650
# Epoch 21/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0955 - binary_accuracy: 0.0812 - val_loss: 0.1670 - val_binary_accuracy: 0.2750
# Epoch 22/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0926 - binary_accuracy: 0.1040 - val_loss: 0.1658 - val_binary_accuracy: 0.2650
# Epoch 23/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0825 - binary_accuracy: 0.0715 - val_loss: 0.1641 - val_binary_accuracy: 0.2400
# Epoch 24/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0779 - binary_accuracy: 0.0470 - val_loss: 0.1626 - val_binary_accuracy: 0.2500
# Epoch 25/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0801 - binary_accuracy: 0.0671 - val_loss: 0.1643 - val_binary_accuracy: 0.2600
# Epoch 26/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0752 - binary_accuracy: 0.0641 - val_loss: 0.1635 - val_binary_accuracy: 0.2550
# Epoch 27/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0702 - binary_accuracy: 0.0630 - val_loss: 0.1621 - val_binary_accuracy: 0.2500
# Epoch 28/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0682 - binary_accuracy: 0.0327 - val_loss: 0.1648 - val_binary_accuracy: 0.2500
# Epoch 29/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0707 - binary_accuracy: 0.0531 - val_loss: 0.1633 - val_binary_accuracy: 0.2450
# Epoch 30/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0605 - binary_accuracy: 0.0295 - val_loss: 0.1647 - val_binary_accuracy: 0.2650
# Epoch 31/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0653 - binary_accuracy: 0.0362 - val_loss: 0.1636 - val_binary_accuracy: 0.2450
# Epoch 32/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0658 - binary_accuracy: 0.0540 - val_loss: 0.1610 - val_binary_accuracy: 0.2450
# Epoch 33/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0692 - binary_accuracy: 0.0661 - val_loss: 0.1609 - val_binary_accuracy: 0.2350
# Epoch 34/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0538 - binary_accuracy: 0.0152 - val_loss: 0.1616 - val_binary_accuracy: 0.2550
# Epoch 35/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0542 - binary_accuracy: 0.0415 - val_loss: 0.1577 - val_binary_accuracy: 0.2550
# Epoch 36/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0514 - binary_accuracy: 0.0155 - val_loss: 0.1575 - val_binary_accuracy: 0.2450
# Epoch 37/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0497 - binary_accuracy: 0.0135 - val_loss: 0.1598 - val_binary_accuracy: 0.2550
# Epoch 38/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0466 - binary_accuracy: 0.0086 - val_loss: 0.1580 - val_binary_accuracy: 0.2600
# Epoch 39/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0479 - binary_accuracy: 0.0225 - val_loss: 0.1567 - val_binary_accuracy: 0.2500
# Epoch 40/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0491 - binary_accuracy: 0.0172 - val_loss: 0.1598 - val_binary_accuracy: 0.2550
# Epoch 41/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0493 - binary_accuracy: 0.0178 - val_loss: 0.1644 - val_binary_accuracy: 0.2650
# Epoch 42/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0518 - binary_accuracy: 0.0082 - val_loss: 0.1610 - val_binary_accuracy: 0.2550
# Epoch 43/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0458 - binary_accuracy: 0.0073 - val_loss: 0.1586 - val_binary_accuracy: 0.2650
# Epoch 44/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0415 - binary_accuracy: 0.0172 - val_loss: 0.1591 - val_binary_accuracy: 0.2600
# Epoch 45/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0381 - binary_accuracy: 0.0108 - val_loss: 0.1593 - val_binary_accuracy: 0.2550
# Epoch 46/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0411 - binary_accuracy: 0.0154 - val_loss: 0.1564 - val_binary_accuracy: 0.2250
# Epoch 47/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0437 - binary_accuracy: 0.0234 - val_loss: 0.1585 - val_binary_accuracy: 0.2300
# Epoch 48/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0392 - binary_accuracy: 0.0096 - val_loss: 0.1606 - val_binary_accuracy: 0.2600
# Epoch 49/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0371 - binary_accuracy: 0.0037 - val_loss: 0.1651 - val_binary_accuracy: 0.2550
# Epoch 50/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0290 - binary_accuracy: 0.0086 - val_loss: 0.1667 - val_binary_accuracy: 0.2450
# Epoch 51/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0376 - binary_accuracy: 0.0080 - val_loss: 0.1652 - val_binary_accuracy: 0.2550
# Epoch 52/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0360 - binary_accuracy: 0.0037 - val_loss: 0.1637 - val_binary_accuracy: 0.2600
# Epoch 53/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0365 - binary_accuracy: 0.0069 - val_loss: 0.1622 - val_binary_accuracy: 0.2600
# Epoch 54/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0323 - binary_accuracy: 0.0000e+00 - val_loss: 0.1647 - val_binary_accuracy: 0.2550
# Epoch 55/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0373 - binary_accuracy: 0.0115 - val_loss: 0.1663 - val_binary_accuracy: 0.2650
# Epoch 56/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0297 - binary_accuracy: 0.0073 - val_loss: 0.1636 - val_binary_accuracy: 0.2900
# Epoch 57/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0267 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2650
# Epoch 58/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0324 - binary_accuracy: 0.0000e+00 - val_loss: 0.1623 - val_binary_accuracy: 0.2550
# Epoch 59/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0393 - binary_accuracy: 0.0177 - val_loss: 0.1649 - val_binary_accuracy: 0.2650
# Epoch 60/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0307 - binary_accuracy: 0.0000e+00 - val_loss: 0.1628 - val_binary_accuracy: 0.2700
# Epoch 61/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0331 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2800
# Epoch 62/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0265 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2650
# Epoch 63/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0314 - binary_accuracy: 0.0027 - val_loss: 0.1615 - val_binary_accuracy: 0.2500
# Epoch 64/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0327 - binary_accuracy: 0.0000e+00 - val_loss: 0.1616 - val_binary_accuracy: 0.2400
# Epoch 65/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0295 - binary_accuracy: 0.0000e+00 - val_loss: 0.1649 - val_binary_accuracy: 0.2700
# Epoch 66/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0237 - binary_accuracy: 0.0000e+00 - val_loss: 0.1709 - val_binary_accuracy: 0.2900
# Epoch 67/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0295 - binary_accuracy: 0.0000e+00 - val_loss: 0.1649 - val_binary_accuracy: 0.2650
# Epoch 68/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0263 - binary_accuracy: 0.0000e+00 - val_loss: 0.1604 - val_binary_accuracy: 0.2300
# Epoch 69/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0324 - binary_accuracy: 0.0027 - val_loss: 0.1573 - val_binary_accuracy: 0.2400
# Epoch 70/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0238 - binary_accuracy: 0.0050 - val_loss: 0.1601 - val_binary_accuracy: 0.2500
# Epoch 71/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0266 - binary_accuracy: 0.0000e+00 - val_loss: 0.1596 - val_binary_accuracy: 0.2500
# Epoch 72/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0233 - binary_accuracy: 0.0000e+00 - val_loss: 0.1619 - val_binary_accuracy: 0.2450
# Epoch 73/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0232 - binary_accuracy: 0.0000e+00 - val_loss: 0.1624 - val_binary_accuracy: 0.2400
# Epoch 74/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0234 - binary_accuracy: 0.0000e+00 - val_loss: 0.1595 - val_binary_accuracy: 0.2350
# Epoch 75/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0231 - binary_accuracy: 0.0000e+00 - val_loss: 0.1594 - val_binary_accuracy: 0.2450
# Epoch 76/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0255 - binary_accuracy: 0.0000e+00 - val_loss: 0.1593 - val_binary_accuracy: 0.2400
# Epoch 77/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0251 - binary_accuracy: 0.0000e+00 - val_loss: 0.1599 - val_binary_accuracy: 0.2400
# Epoch 78/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0267 - binary_accuracy: 0.0000e+00 - val_loss: 0.1613 - val_binary_accuracy: 0.2350
# Epoch 79/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0208 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2350
# Epoch 80/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0236 - binary_accuracy: 0.0000e+00 - val_loss: 0.1615 - val_binary_accuracy: 0.2450
# Epoch 81/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0236 - binary_accuracy: 0.0000e+00 - val_loss: 0.1589 - val_binary_accuracy: 0.2500
# Epoch 82/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0237 - binary_accuracy: 0.0000e+00 - val_loss: 0.1587 - val_binary_accuracy: 0.2400
# Epoch 83/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0236 - binary_accuracy: 0.0000e+00 - val_loss: 0.1609 - val_binary_accuracy: 0.2500
# Epoch 84/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0250 - binary_accuracy: 0.0000e+00 - val_loss: 0.1632 - val_binary_accuracy: 0.2550
# Epoch 85/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0229 - binary_accuracy: 0.0000e+00 - val_loss: 0.1665 - val_binary_accuracy: 0.2600
# Epoch 86/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0210 - binary_accuracy: 0.0000e+00 - val_loss: 0.1659 - val_binary_accuracy: 0.2600
# Epoch 87/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0206 - binary_accuracy: 0.0000e+00 - val_loss: 0.1640 - val_binary_accuracy: 0.2650
# Epoch 88/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0214 - binary_accuracy: 0.0000e+00 - val_loss: 0.1624 - val_binary_accuracy: 0.2600
# Epoch 89/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0156 - binary_accuracy: 0.0000e+00 - val_loss: 0.1627 - val_binary_accuracy: 0.2600
# Epoch 90/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0211 - binary_accuracy: 0.0000e+00 - val_loss: 0.1633 - val_binary_accuracy: 0.2650
# Epoch 91/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0216 - binary_accuracy: 0.0000e+00 - val_loss: 0.1636 - val_binary_accuracy: 0.2550
# Epoch 92/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0188 - binary_accuracy: 0.0000e+00 - val_loss: 0.1612 - val_binary_accuracy: 0.2550
# Epoch 93/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0151 - binary_accuracy: 0.0000e+00 - val_loss: 0.1617 - val_binary_accuracy: 0.2450
# Epoch 94/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0206 - binary_accuracy: 0.0000e+00 - val_loss: 0.1605 - val_binary_accuracy: 0.2300
# Epoch 95/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0162 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2550
# Epoch 96/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0192 - binary_accuracy: 0.0000e+00 - val_loss: 0.1569 - val_binary_accuracy: 0.2500
# Epoch 97/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0213 - binary_accuracy: 0.0000e+00 - val_loss: 0.1610 - val_binary_accuracy: 0.2350
# Epoch 98/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0202 - binary_accuracy: 0.0000e+00 - val_loss: 0.1623 - val_binary_accuracy: 0.2500
# Epoch 99/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0183 - binary_accuracy: 0.0000e+00 - val_loss: 0.1628 - val_binary_accuracy: 0.2450
# Epoch 100/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0178 - binary_accuracy: 0.0000e+00 - val_loss: 0.1625 - val_binary_accuracy: 0.2450
# Epoch 101/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0146 - binary_accuracy: 0.0000e+00 - val_loss: 0.1628 - val_binary_accuracy: 0.2400
# Epoch 102/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0163 - binary_accuracy: 0.0000e+00 - val_loss: 0.1643 - val_binary_accuracy: 0.2300
# Epoch 103/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0195 - binary_accuracy: 0.0000e+00 - val_loss: 0.1606 - val_binary_accuracy: 0.2400
# Epoch 104/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0163 - binary_accuracy: 0.0000e+00 - val_loss: 0.1592 - val_binary_accuracy: 0.2350
# Epoch 105/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0196 - binary_accuracy: 0.0000e+00 - val_loss: 0.1598 - val_binary_accuracy: 0.2400
# Epoch 106/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0146 - binary_accuracy: 0.0000e+00 - val_loss: 0.1591 - val_binary_accuracy: 0.2500
# Epoch 107/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0186 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2400
# Epoch 108/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0185 - binary_accuracy: 0.0000e+00 - val_loss: 0.1573 - val_binary_accuracy: 0.2500
# Epoch 109/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0199 - binary_accuracy: 0.0000e+00 - val_loss: 0.1582 - val_binary_accuracy: 0.2550
# Epoch 110/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0174 - binary_accuracy: 0.0000e+00 - val_loss: 0.1605 - val_binary_accuracy: 0.2550
# Epoch 111/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0156 - binary_accuracy: 0.0000e+00 - val_loss: 0.1638 - val_binary_accuracy: 0.2550
# Epoch 112/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0158 - binary_accuracy: 0.0000e+00 - val_loss: 0.1629 - val_binary_accuracy: 0.2550
# Epoch 113/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0136 - binary_accuracy: 0.0000e+00 - val_loss: 0.1617 - val_binary_accuracy: 0.2650
# Epoch 114/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0155 - binary_accuracy: 0.0000e+00 - val_loss: 0.1612 - val_binary_accuracy: 0.2600
# Epoch 115/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0144 - binary_accuracy: 0.0000e+00 - val_loss: 0.1619 - val_binary_accuracy: 0.2400
# Epoch 116/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0178 - binary_accuracy: 0.0000e+00 - val_loss: 0.1607 - val_binary_accuracy: 0.2500
# Epoch 117/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0181 - binary_accuracy: 0.0000e+00 - val_loss: 0.1600 - val_binary_accuracy: 0.2450
# Epoch 118/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0207 - binary_accuracy: 0.0000e+00 - val_loss: 0.1616 - val_binary_accuracy: 0.2500
# Epoch 119/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0176 - binary_accuracy: 0.0000e+00 - val_loss: 0.1616 - val_binary_accuracy: 0.2700
# Epoch 120/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0140 - binary_accuracy: 0.0000e+00 - val_loss: 0.1612 - val_binary_accuracy: 0.2500
# Epoch 121/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0176 - binary_accuracy: 0.0000e+00 - val_loss: 0.1613 - val_binary_accuracy: 0.2550
# Epoch 122/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0148 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2400
# Epoch 123/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0172 - binary_accuracy: 0.0000e+00 - val_loss: 0.1625 - val_binary_accuracy: 0.2450
# Epoch 124/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0155 - binary_accuracy: 0.0000e+00 - val_loss: 0.1624 - val_binary_accuracy: 0.2650
# Epoch 125/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0152 - binary_accuracy: 0.0000e+00 - val_loss: 0.1629 - val_binary_accuracy: 0.2650
# Epoch 126/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0119 - binary_accuracy: 0.0000e+00 - val_loss: 0.1636 - val_binary_accuracy: 0.2700
# Epoch 127/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0151 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2550
# Epoch 128/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0142 - binary_accuracy: 0.0000e+00 - val_loss: 0.1593 - val_binary_accuracy: 0.2450
# Epoch 129/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0145 - binary_accuracy: 0.0000e+00 - val_loss: 0.1607 - val_binary_accuracy: 0.2500
# Epoch 130/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0153 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2550
# Epoch 131/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0159 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2600
# Epoch 132/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0157 - binary_accuracy: 0.0000e+00 - val_loss: 0.1613 - val_binary_accuracy: 0.2500
# Epoch 133/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0165 - binary_accuracy: 0.0000e+00 - val_loss: 0.1623 - val_binary_accuracy: 0.2450
# Epoch 134/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0133 - binary_accuracy: 0.0000e+00 - val_loss: 0.1627 - val_binary_accuracy: 0.2450
# Epoch 135/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0140 - binary_accuracy: 0.0000e+00 - val_loss: 0.1606 - val_binary_accuracy: 0.2450
# Epoch 136/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0147 - binary_accuracy: 0.0000e+00 - val_loss: 0.1605 - val_binary_accuracy: 0.2450
# Epoch 137/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0128 - binary_accuracy: 0.0000e+00 - val_loss: 0.1608 - val_binary_accuracy: 0.2300
# Epoch 138/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0144 - binary_accuracy: 0.0000e+00 - val_loss: 0.1638 - val_binary_accuracy: 0.2400
# Epoch 139/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0155 - binary_accuracy: 0.0000e+00 - val_loss: 0.1630 - val_binary_accuracy: 0.2500
# Epoch 140/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0158 - binary_accuracy: 0.0000e+00 - val_loss: 0.1637 - val_binary_accuracy: 0.2700
# Epoch 141/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0136 - binary_accuracy: 0.0000e+00 - val_loss: 0.1658 - val_binary_accuracy: 0.2650
# Epoch 142/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0131 - binary_accuracy: 0.0000e+00 - val_loss: 0.1645 - val_binary_accuracy: 0.2500
# Epoch 143/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0139 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2600
# Epoch 144/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0143 - binary_accuracy: 0.0000e+00 - val_loss: 0.1628 - val_binary_accuracy: 0.2550
# Epoch 145/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0144 - binary_accuracy: 0.0000e+00 - val_loss: 0.1675 - val_binary_accuracy: 0.2150
# Epoch 146/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0157 - binary_accuracy: 0.0000e+00 - val_loss: 0.1649 - val_binary_accuracy: 0.2400
# Epoch 147/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0148 - binary_accuracy: 0.0000e+00 - val_loss: 0.1635 - val_binary_accuracy: 0.2400
# Epoch 148/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0131 - binary_accuracy: 0.0000e+00 - val_loss: 0.1659 - val_binary_accuracy: 0.2400
# Epoch 149/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0133 - binary_accuracy: 0.0000e+00 - val_loss: 0.1649 - val_binary_accuracy: 0.2400
# Epoch 150/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0130 - binary_accuracy: 0.0000e+00 - val_loss: 0.1646 - val_binary_accuracy: 0.2600
# Epoch 151/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0162 - binary_accuracy: 0.0000e+00 - val_loss: 0.1646 - val_binary_accuracy: 0.2550
# Epoch 152/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0122 - binary_accuracy: 0.0000e+00 - val_loss: 0.1629 - val_binary_accuracy: 0.2550
# Epoch 153/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0136 - binary_accuracy: 0.0000e+00 - val_loss: 0.1604 - val_binary_accuracy: 0.2450
# Epoch 154/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0154 - binary_accuracy: 0.0000e+00 - val_loss: 0.1584 - val_binary_accuracy: 0.2450
# Epoch 155/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0124 - binary_accuracy: 0.0000e+00 - val_loss: 0.1597 - val_binary_accuracy: 0.2500
# Epoch 156/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0163 - binary_accuracy: 0.0000e+00 - val_loss: 0.1614 - val_binary_accuracy: 0.2400
# Epoch 157/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0136 - binary_accuracy: 0.0000e+00 - val_loss: 0.1605 - val_binary_accuracy: 0.2400
# Epoch 158/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0124 - binary_accuracy: 0.0000e+00 - val_loss: 0.1607 - val_binary_accuracy: 0.2300
# Epoch 159/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0132 - binary_accuracy: 0.0000e+00 - val_loss: 0.1607 - val_binary_accuracy: 0.2300
# Epoch 160/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0135 - binary_accuracy: 0.0000e+00 - val_loss: 0.1615 - val_binary_accuracy: 0.2600
# Epoch 161/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0155 - binary_accuracy: 0.0000e+00 - val_loss: 0.1649 - val_binary_accuracy: 0.2500
# Epoch 162/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0123 - binary_accuracy: 0.0000e+00 - val_loss: 0.1642 - val_binary_accuracy: 0.2600
# Epoch 163/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0123 - binary_accuracy: 0.0000e+00 - val_loss: 0.1658 - val_binary_accuracy: 0.2650
# Epoch 164/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0132 - binary_accuracy: 0.0000e+00 - val_loss: 0.1652 - val_binary_accuracy: 0.2600
# Epoch 165/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0166 - binary_accuracy: 0.0000e+00 - val_loss: 0.1631 - val_binary_accuracy: 0.2700
# Epoch 166/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0124 - binary_accuracy: 0.0000e+00 - val_loss: 0.1617 - val_binary_accuracy: 0.2650
# Epoch 167/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0145 - binary_accuracy: 0.0000e+00 - val_loss: 0.1609 - val_binary_accuracy: 0.2500
# Epoch 168/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0141 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2500
# Epoch 169/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0126 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2650
# Epoch 170/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0124 - binary_accuracy: 0.0000e+00 - val_loss: 0.1628 - val_binary_accuracy: 0.2500
# Epoch 171/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0146 - binary_accuracy: 0.0000e+00 - val_loss: 0.1648 - val_binary_accuracy: 0.2350
# Epoch 172/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0125 - binary_accuracy: 0.0000e+00 - val_loss: 0.1627 - val_binary_accuracy: 0.2600
# Epoch 173/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0132 - binary_accuracy: 0.0000e+00 - val_loss: 0.1621 - val_binary_accuracy: 0.2700
# Epoch 174/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0133 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2650
# Epoch 175/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0126 - binary_accuracy: 0.0000e+00 - val_loss: 0.1636 - val_binary_accuracy: 0.2450
# Epoch 176/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1631 - val_binary_accuracy: 0.2750
# Epoch 177/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0137 - binary_accuracy: 0.0000e+00 - val_loss: 0.1615 - val_binary_accuracy: 0.2600
# Epoch 178/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0138 - binary_accuracy: 0.0000e+00 - val_loss: 0.1606 - val_binary_accuracy: 0.2650
# Epoch 179/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0119 - binary_accuracy: 0.0000e+00 - val_loss: 0.1608 - val_binary_accuracy: 0.2650
# Epoch 180/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0159 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2600
# Epoch 181/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0125 - binary_accuracy: 0.0000e+00 - val_loss: 0.1622 - val_binary_accuracy: 0.2600
# Epoch 182/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0127 - binary_accuracy: 0.0000e+00 - val_loss: 0.1638 - val_binary_accuracy: 0.2650
# Epoch 183/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0122 - binary_accuracy: 0.0000e+00 - val_loss: 0.1635 - val_binary_accuracy: 0.2550
# Epoch 184/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0107 - binary_accuracy: 0.0000e+00 - val_loss: 0.1612 - val_binary_accuracy: 0.2400
# Epoch 185/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0099 - binary_accuracy: 0.0000e+00 - val_loss: 0.1588 - val_binary_accuracy: 0.2600
# Epoch 186/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0124 - binary_accuracy: 0.0000e+00 - val_loss: 0.1582 - val_binary_accuracy: 0.2650
# Epoch 187/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0126 - binary_accuracy: 0.0000e+00 - val_loss: 0.1573 - val_binary_accuracy: 0.2450
# Epoch 188/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0091 - binary_accuracy: 0.0000e+00 - val_loss: 0.1585 - val_binary_accuracy: 0.2300
# Epoch 189/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0119 - binary_accuracy: 0.0000e+00 - val_loss: 0.1600 - val_binary_accuracy: 0.2750
# Epoch 190/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0126 - binary_accuracy: 0.0000e+00 - val_loss: 0.1622 - val_binary_accuracy: 0.2700
# Epoch 191/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0108 - binary_accuracy: 0.0000e+00 - val_loss: 0.1620 - val_binary_accuracy: 0.2550
# Epoch 192/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0126 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2650
# Epoch 193/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0132 - binary_accuracy: 0.0000e+00 - val_loss: 0.1596 - val_binary_accuracy: 0.2550
# Epoch 194/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0118 - binary_accuracy: 0.0000e+00 - val_loss: 0.1604 - val_binary_accuracy: 0.2550
# Epoch 195/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0134 - binary_accuracy: 0.0000e+00 - val_loss: 0.1598 - val_binary_accuracy: 0.2450
# Epoch 196/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0099 - binary_accuracy: 0.0000e+00 - val_loss: 0.1610 - val_binary_accuracy: 0.2600
# Epoch 197/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0124 - binary_accuracy: 0.0000e+00 - val_loss: 0.1624 - val_binary_accuracy: 0.2450
# Epoch 198/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0105 - binary_accuracy: 0.0000e+00 - val_loss: 0.1605 - val_binary_accuracy: 0.2500
# Epoch 199/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0096 - binary_accuracy: 0.0000e+00 - val_loss: 0.1600 - val_binary_accuracy: 0.2550
# Epoch 200/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0100 - binary_accuracy: 0.0000e+00 - val_loss: 0.1613 - val_binary_accuracy: 0.2600
# Epoch 201/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0099 - binary_accuracy: 0.0000e+00 - val_loss: 0.1623 - val_binary_accuracy: 0.2650
# Epoch 202/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0108 - binary_accuracy: 0.0000e+00 - val_loss: 0.1636 - val_binary_accuracy: 0.2700
# Epoch 203/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0111 - binary_accuracy: 0.0000e+00 - val_loss: 0.1644 - val_binary_accuracy: 0.2750
# Epoch 204/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0106 - binary_accuracy: 0.0000e+00 - val_loss: 0.1631 - val_binary_accuracy: 0.2750
# Epoch 205/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0108 - binary_accuracy: 0.0000e+00 - val_loss: 0.1631 - val_binary_accuracy: 0.2700
# Epoch 206/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0105 - binary_accuracy: 0.0000e+00 - val_loss: 0.1633 - val_binary_accuracy: 0.2550
# Epoch 207/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1620 - val_binary_accuracy: 0.2750
# Epoch 208/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0106 - binary_accuracy: 0.0000e+00 - val_loss: 0.1615 - val_binary_accuracy: 0.2550
# Epoch 209/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0127 - binary_accuracy: 0.0000e+00 - val_loss: 0.1579 - val_binary_accuracy: 0.2450
# Epoch 210/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0112 - binary_accuracy: 0.0000e+00 - val_loss: 0.1575 - val_binary_accuracy: 0.2450
# Epoch 211/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0113 - binary_accuracy: 0.0000e+00 - val_loss: 0.1549 - val_binary_accuracy: 0.2550
# Epoch 212/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0103 - binary_accuracy: 0.0000e+00 - val_loss: 0.1566 - val_binary_accuracy: 0.2650
# Epoch 213/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0102 - binary_accuracy: 0.0000e+00 - val_loss: 0.1581 - val_binary_accuracy: 0.2450
# Epoch 214/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0105 - binary_accuracy: 0.0000e+00 - val_loss: 0.1572 - val_binary_accuracy: 0.2450
# Epoch 215/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0110 - binary_accuracy: 0.0000e+00 - val_loss: 0.1562 - val_binary_accuracy: 0.2450
# Epoch 216/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0144 - binary_accuracy: 0.0000e+00 - val_loss: 0.1585 - val_binary_accuracy: 0.2550
# Epoch 217/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0086 - binary_accuracy: 0.0000e+00 - val_loss: 0.1582 - val_binary_accuracy: 0.2600
# Epoch 218/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0095 - binary_accuracy: 0.0000e+00 - val_loss: 0.1575 - val_binary_accuracy: 0.2450
# Epoch 219/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0093 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2350
# Epoch 220/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0137 - binary_accuracy: 0.0000e+00 - val_loss: 0.1559 - val_binary_accuracy: 0.2400
# Epoch 221/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - binary_accuracy: 0.0000e+00 - val_loss: 0.1564 - val_binary_accuracy: 0.2550
# Epoch 222/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0109 - binary_accuracy: 0.0000e+00 - val_loss: 0.1591 - val_binary_accuracy: 0.2600
# Epoch 223/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0104 - binary_accuracy: 0.0000e+00 - val_loss: 0.1599 - val_binary_accuracy: 0.2550
# Epoch 224/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0115 - binary_accuracy: 0.0000e+00 - val_loss: 0.1592 - val_binary_accuracy: 0.2550
# Epoch 225/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0093 - binary_accuracy: 0.0000e+00 - val_loss: 0.1586 - val_binary_accuracy: 0.2550
# Epoch 226/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0105 - binary_accuracy: 0.0000e+00 - val_loss: 0.1574 - val_binary_accuracy: 0.2550
# Epoch 227/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0104 - binary_accuracy: 0.0000e+00 - val_loss: 0.1564 - val_binary_accuracy: 0.2350
# Epoch 228/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2500
# Epoch 229/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0100 - binary_accuracy: 0.0000e+00 - val_loss: 0.1578 - val_binary_accuracy: 0.2550
# Epoch 230/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0109 - binary_accuracy: 0.0000e+00 - val_loss: 0.1569 - val_binary_accuracy: 0.2600
# Epoch 231/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0107 - binary_accuracy: 0.0000e+00 - val_loss: 0.1572 - val_binary_accuracy: 0.2550
# Epoch 232/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1581 - val_binary_accuracy: 0.2400
# Epoch 233/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0102 - binary_accuracy: 0.0000e+00 - val_loss: 0.1588 - val_binary_accuracy: 0.2500
# Epoch 234/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0093 - binary_accuracy: 0.0000e+00 - val_loss: 0.1599 - val_binary_accuracy: 0.2550
# Epoch 235/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0095 - binary_accuracy: 0.0000e+00 - val_loss: 0.1590 - val_binary_accuracy: 0.2500
# Epoch 236/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0104 - binary_accuracy: 0.0000e+00 - val_loss: 0.1562 - val_binary_accuracy: 0.2400
# Epoch 237/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0099 - binary_accuracy: 0.0000e+00 - val_loss: 0.1568 - val_binary_accuracy: 0.2350
# Epoch 238/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0120 - binary_accuracy: 0.0000e+00 - val_loss: 0.1578 - val_binary_accuracy: 0.2450
# Epoch 239/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0094 - binary_accuracy: 0.0000e+00 - val_loss: 0.1579 - val_binary_accuracy: 0.2550
# Epoch 240/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0102 - binary_accuracy: 0.0000e+00 - val_loss: 0.1593 - val_binary_accuracy: 0.2500
# Epoch 241/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0103 - binary_accuracy: 0.0000e+00 - val_loss: 0.1596 - val_binary_accuracy: 0.2400
# Epoch 242/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1594 - val_binary_accuracy: 0.2400
# Epoch 243/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0091 - binary_accuracy: 0.0000e+00 - val_loss: 0.1603 - val_binary_accuracy: 0.2450
# Epoch 244/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2600
# Epoch 245/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1613 - val_binary_accuracy: 0.2550
# Epoch 246/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0103 - binary_accuracy: 0.0000e+00 - val_loss: 0.1585 - val_binary_accuracy: 0.2450
# Epoch 247/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0104 - binary_accuracy: 0.0000e+00 - val_loss: 0.1578 - val_binary_accuracy: 0.2450
# Epoch 248/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0123 - binary_accuracy: 0.0000e+00 - val_loss: 0.1587 - val_binary_accuracy: 0.2300
# Epoch 249/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0105 - binary_accuracy: 0.0000e+00 - val_loss: 0.1588 - val_binary_accuracy: 0.2400
# Epoch 250/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0092 - binary_accuracy: 0.0000e+00 - val_loss: 0.1586 - val_binary_accuracy: 0.2450
# Epoch 251/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2500
# Epoch 252/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0082 - binary_accuracy: 0.0000e+00 - val_loss: 0.1567 - val_binary_accuracy: 0.2500
# Epoch 253/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0097 - binary_accuracy: 0.0000e+00 - val_loss: 0.1568 - val_binary_accuracy: 0.2400
# Epoch 254/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1563 - val_binary_accuracy: 0.2400
# Epoch 255/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0102 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2450
# Epoch 256/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0092 - binary_accuracy: 0.0000e+00 - val_loss: 0.1583 - val_binary_accuracy: 0.2450
# Epoch 257/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0099 - binary_accuracy: 0.0000e+00 - val_loss: 0.1596 - val_binary_accuracy: 0.2600
# Epoch 258/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0100 - binary_accuracy: 0.0000e+00 - val_loss: 0.1589 - val_binary_accuracy: 0.2400
# Epoch 259/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0092 - binary_accuracy: 0.0000e+00 - val_loss: 0.1574 - val_binary_accuracy: 0.2350
# Epoch 260/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0083 - binary_accuracy: 0.0000e+00 - val_loss: 0.1584 - val_binary_accuracy: 0.2500
# Epoch 261/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1587 - val_binary_accuracy: 0.2450
# Epoch 262/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0108 - binary_accuracy: 0.0000e+00 - val_loss: 0.1604 - val_binary_accuracy: 0.2500
# Epoch 263/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0109 - binary_accuracy: 0.0000e+00 - val_loss: 0.1609 - val_binary_accuracy: 0.2450
# Epoch 264/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0113 - binary_accuracy: 0.0000e+00 - val_loss: 0.1598 - val_binary_accuracy: 0.2450
# Epoch 265/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0095 - binary_accuracy: 0.0000e+00 - val_loss: 0.1596 - val_binary_accuracy: 0.2450
# Epoch 266/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0113 - binary_accuracy: 0.0000e+00 - val_loss: 0.1591 - val_binary_accuracy: 0.2400
# Epoch 267/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0092 - binary_accuracy: 0.0000e+00 - val_loss: 0.1582 - val_binary_accuracy: 0.2400
# Epoch 268/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0107 - binary_accuracy: 0.0000e+00 - val_loss: 0.1577 - val_binary_accuracy: 0.2450
# Epoch 269/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0077 - binary_accuracy: 0.0000e+00 - val_loss: 0.1583 - val_binary_accuracy: 0.2400
# Epoch 270/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0080 - binary_accuracy: 0.0000e+00 - val_loss: 0.1587 - val_binary_accuracy: 0.2450
# Epoch 271/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1600 - val_binary_accuracy: 0.2500
# Epoch 272/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1609 - val_binary_accuracy: 0.2550
# Epoch 273/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0085 - binary_accuracy: 0.0000e+00 - val_loss: 0.1609 - val_binary_accuracy: 0.2250
# Epoch 274/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0102 - binary_accuracy: 0.0000e+00 - val_loss: 0.1588 - val_binary_accuracy: 0.2450
# Epoch 275/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0094 - binary_accuracy: 0.0000e+00 - val_loss: 0.1580 - val_binary_accuracy: 0.2450
# Epoch 276/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0097 - binary_accuracy: 0.0000e+00 - val_loss: 0.1575 - val_binary_accuracy: 0.2300
# Epoch 277/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0087 - binary_accuracy: 0.0000e+00 - val_loss: 0.1582 - val_binary_accuracy: 0.2350
# Epoch 278/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0090 - binary_accuracy: 0.0000e+00 - val_loss: 0.1599 - val_binary_accuracy: 0.2450
# Epoch 279/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0091 - binary_accuracy: 0.0000e+00 - val_loss: 0.1596 - val_binary_accuracy: 0.2300
# Epoch 280/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0104 - binary_accuracy: 0.0000e+00 - val_loss: 0.1589 - val_binary_accuracy: 0.2400
# Epoch 281/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1594 - val_binary_accuracy: 0.2400
# Epoch 282/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0096 - binary_accuracy: 0.0000e+00 - val_loss: 0.1587 - val_binary_accuracy: 0.2350
# Epoch 283/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - binary_accuracy: 0.0000e+00 - val_loss: 0.1581 - val_binary_accuracy: 0.2350
# Epoch 284/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0098 - binary_accuracy: 0.0000e+00 - val_loss: 0.1590 - val_binary_accuracy: 0.2550
# Epoch 285/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0088 - binary_accuracy: 0.0000e+00 - val_loss: 0.1582 - val_binary_accuracy: 0.2600
# Epoch 286/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0082 - binary_accuracy: 0.0000e+00 - val_loss: 0.1571 - val_binary_accuracy: 0.2350
# Epoch 287/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0094 - binary_accuracy: 0.0000e+00 - val_loss: 0.1555 - val_binary_accuracy: 0.2200
# Epoch 288/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0095 - binary_accuracy: 0.0069 - val_loss: 0.1569 - val_binary_accuracy: 0.2450
# Epoch 289/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0083 - binary_accuracy: 0.0000e+00 - val_loss: 0.1565 - val_binary_accuracy: 0.2400
# Epoch 290/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1587 - val_binary_accuracy: 0.2450
# Epoch 291/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0089 - binary_accuracy: 0.0000e+00 - val_loss: 0.1617 - val_binary_accuracy: 0.2650
# Epoch 292/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0101 - binary_accuracy: 0.0000e+00 - val_loss: 0.1579 - val_binary_accuracy: 0.2450
# Epoch 293/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0092 - binary_accuracy: 0.0000e+00 - val_loss: 0.1565 - val_binary_accuracy: 0.2250
# Epoch 294/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0084 - binary_accuracy: 0.0000e+00 - val_loss: 0.1578 - val_binary_accuracy: 0.2400
# Epoch 295/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0091 - binary_accuracy: 0.0000e+00 - val_loss: 0.1598 - val_binary_accuracy: 0.2300
# Epoch 296/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0090 - binary_accuracy: 0.0000e+00 - val_loss: 0.1618 - val_binary_accuracy: 0.2500
# Epoch 297/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0074 - binary_accuracy: 0.0000e+00 - val_loss: 0.1611 - val_binary_accuracy: 0.2400
# Epoch 298/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0103 - binary_accuracy: 0.0000e+00 - val_loss: 0.1626 - val_binary_accuracy: 0.2300
# Epoch 299/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0079 - binary_accuracy: 0.0000e+00 - val_loss: 0.1619 - val_binary_accuracy: 0.2450
# Epoch 300/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0077 - binary_accuracy: 0.0000e+00 - val_loss: 0.1597 - val_binary_accuracy: 0.2400
# Epoch 301/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0099 - binary_accuracy: 0.0000e+00 - val_loss: 0.1589 - val_binary_accuracy: 0.2300
# Epoch 302/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0082 - binary_accuracy: 0.0000e+00 - val_loss: 0.1585 - val_binary_accuracy: 0.2450
# Epoch 303/800
# ...
# Epoch 701/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0063 - binary_accuracy: 0.0000e+00 - val_loss: 0.1694 - val_binary_accuracy: 0.2450
# Epoch 702/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1682 - val_binary_accuracy: 0.2500
# Epoch 703/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0062 - binary_accuracy: 0.0000e+00 - val_loss: 0.1678 - val_binary_accuracy: 0.2550
# Epoch 704/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0053 - binary_accuracy: 0.0000e+00 - val_loss: 0.1703 - val_binary_accuracy: 0.2600
# Epoch 705/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - binary_accuracy: 0.0000e+00 - val_loss: 0.1717 - val_binary_accuracy: 0.2650
# Epoch 706/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0059 - binary_accuracy: 0.0000e+00 - val_loss: 0.1696 - val_binary_accuracy: 0.2500
# Epoch 707/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1671 - val_binary_accuracy: 0.2500
# Epoch 708/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - binary_accuracy: 0.0000e+00 - val_loss: 0.1701 - val_binary_accuracy: 0.2450
# Epoch 709/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1679 - val_binary_accuracy: 0.2500
# Epoch 710/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1689 - val_binary_accuracy: 0.2500
# Epoch 711/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0065 - binary_accuracy: 0.0000e+00 - val_loss: 0.1694 - val_binary_accuracy: 0.2450
# Epoch 712/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0040 - binary_accuracy: 0.0000e+00 - val_loss: 0.1677 - val_binary_accuracy: 0.2350
# Epoch 713/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0056 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2550
# Epoch 714/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1738 - val_binary_accuracy: 0.2650
# Epoch 715/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0060 - binary_accuracy: 0.0000e+00 - val_loss: 0.1708 - val_binary_accuracy: 0.2500
# Epoch 716/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0049 - binary_accuracy: 0.0000e+00 - val_loss: 0.1704 - val_binary_accuracy: 0.2550
# Epoch 717/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1710 - val_binary_accuracy: 0.2450
# Epoch 718/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0056 - binary_accuracy: 0.0000e+00 - val_loss: 0.1694 - val_binary_accuracy: 0.2400
# Epoch 719/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0056 - binary_accuracy: 0.0000e+00 - val_loss: 0.1715 - val_binary_accuracy: 0.2450
# Epoch 720/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0055 - binary_accuracy: 0.0000e+00 - val_loss: 0.1728 - val_binary_accuracy: 0.2500
# Epoch 721/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0064 - binary_accuracy: 0.0000e+00 - val_loss: 0.1719 - val_binary_accuracy: 0.2550
# Epoch 722/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1730 - val_binary_accuracy: 0.2650
# Epoch 723/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1684 - val_binary_accuracy: 0.2400
# Epoch 724/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2750
# Epoch 725/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0065 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2650
# Epoch 726/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1715 - val_binary_accuracy: 0.2450
# Epoch 727/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1736 - val_binary_accuracy: 0.2550
# Epoch 728/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0059 - binary_accuracy: 0.0000e+00 - val_loss: 0.1725 - val_binary_accuracy: 0.2600
# Epoch 729/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - binary_accuracy: 0.0000e+00 - val_loss: 0.1741 - val_binary_accuracy: 0.2700
# Epoch 730/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - binary_accuracy: 0.0000e+00 - val_loss: 0.1709 - val_binary_accuracy: 0.2550
# Epoch 731/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1705 - val_binary_accuracy: 0.2550
# Epoch 732/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1719 - val_binary_accuracy: 0.2650
# Epoch 733/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1722 - val_binary_accuracy: 0.2550
# Epoch 734/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1722 - val_binary_accuracy: 0.2550
# Epoch 735/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0049 - binary_accuracy: 0.0000e+00 - val_loss: 0.1702 - val_binary_accuracy: 0.2500
# Epoch 736/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1698 - val_binary_accuracy: 0.2550
# Epoch 737/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1712 - val_binary_accuracy: 0.2600
# Epoch 738/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1697 - val_binary_accuracy: 0.2500
# Epoch 739/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2500
# Epoch 740/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1737 - val_binary_accuracy: 0.2600
# Epoch 741/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0057 - binary_accuracy: 0.0000e+00 - val_loss: 0.1743 - val_binary_accuracy: 0.2650
# Epoch 742/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - binary_accuracy: 0.0000e+00 - val_loss: 0.1693 - val_binary_accuracy: 0.2500
# Epoch 743/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0046 - binary_accuracy: 0.0000e+00 - val_loss: 0.1697 - val_binary_accuracy: 0.2450
# Epoch 744/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1726 - val_binary_accuracy: 0.2550
# Epoch 745/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0053 - binary_accuracy: 0.0000e+00 - val_loss: 0.1714 - val_binary_accuracy: 0.2550
# Epoch 746/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1728 - val_binary_accuracy: 0.2500
# Epoch 747/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2600
# Epoch 748/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0056 - binary_accuracy: 0.0000e+00 - val_loss: 0.1721 - val_binary_accuracy: 0.2550
# Epoch 749/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1718 - val_binary_accuracy: 0.2500
# Epoch 750/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0055 - binary_accuracy: 0.0000e+00 - val_loss: 0.1752 - val_binary_accuracy: 0.2600
# Epoch 751/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1770 - val_binary_accuracy: 0.2650
# Epoch 752/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - binary_accuracy: 0.0000e+00 - val_loss: 0.1746 - val_binary_accuracy: 0.2550
# Epoch 753/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1725 - val_binary_accuracy: 0.2550
# Epoch 754/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1709 - val_binary_accuracy: 0.2600
# Epoch 755/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0059 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2550
# Epoch 756/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0065 - binary_accuracy: 0.0000e+00 - val_loss: 0.1734 - val_binary_accuracy: 0.2650
# Epoch 757/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0057 - binary_accuracy: 0.0000e+00 - val_loss: 0.1714 - val_binary_accuracy: 0.2550
# Epoch 758/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - binary_accuracy: 0.0000e+00 - val_loss: 0.1727 - val_binary_accuracy: 0.2600
# Epoch 759/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1756 - val_binary_accuracy: 0.2650
# Epoch 760/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0047 - binary_accuracy: 0.0000e+00 - val_loss: 0.1712 - val_binary_accuracy: 0.2600
# Epoch 761/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1729 - val_binary_accuracy: 0.2650
# Epoch 762/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0053 - binary_accuracy: 0.0000e+00 - val_loss: 0.1720 - val_binary_accuracy: 0.2650
# Epoch 763/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0056 - binary_accuracy: 0.0000e+00 - val_loss: 0.1711 - val_binary_accuracy: 0.2600
# Epoch 764/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1737 - val_binary_accuracy: 0.2650
# Epoch 765/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0060 - binary_accuracy: 0.0000e+00 - val_loss: 0.1709 - val_binary_accuracy: 0.2500
# Epoch 766/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1721 - val_binary_accuracy: 0.2550
# Epoch 767/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0044 - binary_accuracy: 0.0000e+00 - val_loss: 0.1741 - val_binary_accuracy: 0.2550
# Epoch 768/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0047 - binary_accuracy: 0.0000e+00 - val_loss: 0.1721 - val_binary_accuracy: 0.2500
# Epoch 769/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1677 - val_binary_accuracy: 0.2400
# Epoch 770/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1693 - val_binary_accuracy: 0.2600
# Epoch 771/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0049 - binary_accuracy: 0.0000e+00 - val_loss: 0.1731 - val_binary_accuracy: 0.2800
# Epoch 772/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1725 - val_binary_accuracy: 0.2800
# Epoch 773/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1739 - val_binary_accuracy: 0.2650
# Epoch 774/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1712 - val_binary_accuracy: 0.2450
# Epoch 775/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1735 - val_binary_accuracy: 0.2650
# Epoch 776/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0044 - binary_accuracy: 0.0000e+00 - val_loss: 0.1739 - val_binary_accuracy: 0.2700
# Epoch 777/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0045 - binary_accuracy: 0.0000e+00 - val_loss: 0.1741 - val_binary_accuracy: 0.2650
# Epoch 778/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - binary_accuracy: 0.0000e+00 - val_loss: 0.1710 - val_binary_accuracy: 0.2550
# Epoch 779/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0049 - binary_accuracy: 0.0000e+00 - val_loss: 0.1727 - val_binary_accuracy: 0.2600
# Epoch 780/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0045 - binary_accuracy: 0.0000e+00 - val_loss: 0.1716 - val_binary_accuracy: 0.2600
# Epoch 781/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0043 - binary_accuracy: 0.0000e+00 - val_loss: 0.1698 - val_binary_accuracy: 0.2550
# Epoch 782/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - binary_accuracy: 0.0000e+00 - val_loss: 0.1731 - val_binary_accuracy: 0.2600
# Epoch 783/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0055 - binary_accuracy: 0.0000e+00 - val_loss: 0.1751 - val_binary_accuracy: 0.2700
# Epoch 784/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1700 - val_binary_accuracy: 0.2500
# Epoch 785/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0047 - binary_accuracy: 0.0000e+00 - val_loss: 0.1724 - val_binary_accuracy: 0.2700
# Epoch 786/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0059 - binary_accuracy: 0.0000e+00 - val_loss: 0.1722 - val_binary_accuracy: 0.2550
# Epoch 787/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1727 - val_binary_accuracy: 0.2600
# Epoch 788/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0052 - binary_accuracy: 0.0000e+00 - val_loss: 0.1730 - val_binary_accuracy: 0.2650
# Epoch 789/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0044 - binary_accuracy: 0.0000e+00 - val_loss: 0.1715 - val_binary_accuracy: 0.2650
# Epoch 790/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0041 - binary_accuracy: 0.0000e+00 - val_loss: 0.1690 - val_binary_accuracy: 0.2450
# Epoch 791/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1717 - val_binary_accuracy: 0.2700
# Epoch 792/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1719 - val_binary_accuracy: 0.2500
# Epoch 793/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - binary_accuracy: 0.0000e+00 - val_loss: 0.1730 - val_binary_accuracy: 0.2600
# Epoch 794/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0060 - binary_accuracy: 0.0000e+00 - val_loss: 0.1739 - val_binary_accuracy: 0.2600
# Epoch 795/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0045 - binary_accuracy: 0.0000e+00 - val_loss: 0.1690 - val_binary_accuracy: 0.2400
# Epoch 796/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1723 - val_binary_accuracy: 0.2450
# Epoch 797/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - binary_accuracy: 0.0000e+00 - val_loss: 0.1762 - val_binary_accuracy: 0.2650
# Epoch 798/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - binary_accuracy: 0.0000e+00 - val_loss: 0.1698 - val_binary_accuracy: 0.2550
# Epoch 799/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0044 - binary_accuracy: 0.0000e+00 - val_loss: 0.1729 - val_binary_accuracy: 0.2600
# Epoch 800/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - binary_accuracy: 0.0000e+00 - val_loss: 0.1714 - val_binary_accuracy: 0.2600

# %%
lg.normalize()

# %%
fig=px.scatter(lg.df, x="f1", y="f2", animation_frame="iterations", color="label",opacity=lg.df.arc,
                range_x=[-1.5,1.5],
              range_y=[-1.5,1.5])
fig.update_yaxes(
    scaleanchor = "x",
    scaleratio = 1,
)

# %%
fig.write_html("history/siamese_euc_dist_tf.html")
