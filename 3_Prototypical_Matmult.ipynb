# %%
# !pip install plotly

# %%
# !pip uninstall -y numpy
# !pip install numpy
# Out:
# Found existing installation: numpy 1.16.6
# Uninstalling numpy-1.16.6:
#   Successfully uninstalled numpy-1.16.6
# Collecting numpy
#   Downloading numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 1.7 MB/s eta 0:00:01
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorlayer 2.1.0 requires numpy<1.17,>=1.16, but you have numpy 1.21.4 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.21.4 which is incompatible.
# tensorflow 2.4.1 requires wrapt~=1.12.1, but you have wrapt 1.11.1 which is incompatible.
# Successfully installed numpy-1.21.4

# %%
import numpy as np
import pandas as pd
import math
import time
from functools import partial

import plotly.express as px

import tensorflow as tf
import tensorflow.keras as keras

from sklearn.model_selection import train_test_split

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
np.random.seed(2021)
tf.random.set_seed(2021)

# %%
num_classes=10

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train_1hot = keras.utils.to_categorical(y_train, num_classes)
y_test_1hot = keras.utils.to_categorical(y_test, num_classes)

# %%
batch_size = 128
meta_batch_size = 32
epochs = 10
plt_x,plt_y=x_test[:batch_size],y_test[:batch_size]

# %%
train_loader = tf.data.Dataset.from_tensor_slices((x_train,y_train))
all_class_list=[train_loader.filter(lambda x,y: y==yy)
                  .cache()
                  .shuffle(2000)
                  .prefetch(50)
                 for yy in range(num_classes)]

# %%
WAYS=5
SHOTS=3
W,H,CH=28,28,1

# %%
def form_meta2(dataset_list,mult=4):
    orders=np.concatenate([np.random.permutation(len(dataset_list)) for x in range(mult)])
    for tasks in range(len(orders)//WAYS):
        #從已決定好的順序拉出WAY個class#
        picked=[dataset_list[tt] for tt in orders[WAYS*tasks:WAYS*(tasks+1)]]
        #每個class抽SHOTS+1張#
        data = [next(iter(class_loader.batch(SHOTS+1)))[0] for class_loader in picked]
        #support每個class各有SHOTS張照片#
        support=tf.concat([d[:-1] for d in data],axis=0)
        #query挑每個class 1 張，順序不固定#
        idxs=np.random.choice(range(WAYS), size=WAYS, replace=False)
        query=tf.concat([data[wayid][-2:-1] for wayid in idxs],axis=0)
        #輸出的時候把support跟query接在一起#
        yield tf.concat([support, query], axis=0), tf.stack([keras.utils.to_categorical(idx,num_classes=WAYS) for idx in idxs], axis=0)

# %%
MULT=40
train_meta_loader=tf.data.Dataset.from_generator(partial(form_meta2,all_class_list,MULT),
                                                 output_types=(tf.float32,tf.float32),
                                                output_shapes=((WAYS*(SHOTS+1),W,H,CH),(WAYS,WAYS)))

# %%
start_time=time.time()
for ld in all_class_list:
    for xx,yy in ld.batch(500):
        pass
print(f"{time.time()-start_time:.03f} sec")
# Out:
# 15.679 sec

# %%
start_time=time.time()
for ld in all_class_list:
    for xx,yy in ld.batch(500):
        pass
print(f"{time.time()-start_time:.03f} sec")
# Out:
# 2.708 sec

# %%
## Embedding ##
class Encoder(keras.Model):
    def __init__(self,n_layers=2,latent_features=2,hidden_featrues=64):
        super().__init__()
        self.latent_features=latent_features
        # First Layer
        self.conv_0=keras.layers.Conv2D(hidden_featrues, kernel_size=3, activation="relu",padding='same')
        self.dropout_0=keras.layers.Dropout(0.2)
        # Middle Layers
        self.convs=[keras.layers.Conv2D(hidden_featrues, kernel_size=3, activation="relu",padding='same') for _ in range(n_layers)]
        self.mxpools = [keras.layers.MaxPooling2D(pool_size=2) for _ in range(n_layers)]
        self.dropouts = [keras.layers.Dropout(0.2) for _ in range(n_layers)]
        # Integration Layer(Output Layer)
        WIDTH=2
        self.gap=keras.layers.AveragePooling2D(pool_size=WIDTH,)
        self.flatten=keras.layers.Flatten()
        self.dense=keras.layers.Dense(latent_features)
      
    def call(self,x):
        x=self.dropout_0(self.conv_0(x))
        for conv,mxp,drp in zip(self.convs,self.mxpools,self.dropouts):
            x=drp(mxp(conv(x)))
        x=self.gap(x)
        x=self.flatten(x)
        y=self.dense(x)
        return y

## Special Layers ##

class MatMul:
    def __init__(self,mode="paired"):
        self.mode=mode
        assert mode in ["paired","cross"]
    def __call__(self,q,s):
        if self.mode=="paired":
            return tf.reduce_sum(tf.multiply(q,s),axis=-1,keepdims=True)
        if self.mode=="cross":
            return tf.matmul(q,s,transpose_b=True)

class EuclideanDist:
    def __init__(self,mode="paired"):
        self.mode=mode
        assert mode in ["paired","cross"]
        
    def __call__(self,q,s):
        if self.mode=="paired":
            dist=tf.math.reduce_euclidean_norm(q-s,axis=-1,keepdims=True)
        if self.mode=="cross":
            dist=-tf.math.reduce_euclidean_norm(
                tf.stack([q[:,qq:qq+1]-s for qq in range(q.shape[1])],axis=1)
                ,axis=-1,keepdims=False)
            
        return dist
            
        


class CosSim:
    def __init__(self,mode="paired"):
        self.mode=mode
        assert mode in ["paired","cross"]
        self.matmul=MatMul(mode)
    def __call__(self,q,s):
        query_n=tf.math.l2_normalize(q, axis=-1)
        support_n=tf.math.l2_normalize(s, axis=-1)
        return self.matmul(query_n,support_n)
    
class CosineLayer(keras.layers.Layer):
    def __init__(self, out_features=10,mode="cross"):
        super().__init__()
        self.out_features = out_features
        self.cos_sim=CosSim(mode)
    def build(self, input_shape):
        self.w = self.add_weight(shape=(self.out_features,input_shape[-1]),
                               initializer='glorot_uniform',
                               trainable=True)
    def call(self, inputs):
        return self.cos_sim(inputs,self.w)

## Loss function ##
class ContrastiveLoss:
    def __init__(self,m=1,mode="dist"):
        
        self.mode=mode
        if self.mode=="dist":
            self.m=m
        if self.mode=="cos" or self.mode=="matmul":
            self.activation=keras.activations.sigmoid
            self.loss_fn=keras.losses.BinaryCrossentropy()
        assert mode in ["dist","cos","matmul"]
        self.__name__="loss"
    def __call__(self,y_true, y_pred):
        if self.mode=="dist":
            loss=tf.reduce_mean(y_true * tf.square(y_pred) +
                                 (1 - y_true)* tf.square(tf.maximum(self.m - y_pred, 0)),
                               axis=-1,keepdims=True)
        if self.mode=="cos" or self.mode=="matmul":
            loss=self.loss_fn(y_true,self.activation(y_pred))
        return loss


class FocalLoss:
    def __init__(self, gamma=3, eps=1e-10):
        self.gamma = gamma
        self.eps = tf.constant(eps)
        self.softmax =keras.layers.Softmax()
        self.cce=keras.losses.CategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
        self.__name__="loss"
    def __call__(self,y_true, y_pred): 
        logp = self.cce(y_true,self.softmax(y_pred+self.eps))
        p = tf.exp(-logp)
        loss = (tf.constant(1.) - p) ** self.gamma * logp
        return tf.reduce_mean(loss, axis=-1)
    
class AddMarginLoss():
    def __init__(self,s=5,m=0.3,gamma=3):
        self.s = s
        self.m = m
        self.lossfn=FocalLoss(gamma)
        self.__name__="loss"
    def __call__(self, y_true, y_pred):
        cosine=y_pred
        phi = cosine - self.m
        # -------------torch.where(out_i = {x_i if condition_i else y_i) -------------
        arc = (y_true * phi) + ((1.0 - y_true) * cosine)  # you can use torch.where if your torch.__version__ is 0.4
        arc *= self.s
        return self.lossfn(y_true,arc)
    
class ArcMarginLoss():
    def __init__(self,s=32,m=0.3,easy_margin=False,gamma=3, eps=1e-6):
        self.s = s
        self.m = m
        self.eps=tf.constant(eps)# This is very, very, very important
        self.easy_margin = easy_margin
        self.cos_m = math.cos(m)
        self.sin_m = math.sin(m)
        self.th = math.cos(math.pi - m)
        self.mm = math.sin(math.pi - m) * m
        
        self.lossfn=FocalLoss(gamma)
        self.__name__="loss"
    def __call__(self, y_true, y_pred):
        cosine=y_pred
        
        sine = tf.sqrt(tf.constant(1.) - tf.pow(cosine, 2) + self.eps)
        
        phi = cosine * self.cos_m - sine * self.sin_m
        if self.easy_margin:
            phi = tf.where(cosine > 0, phi, cosine)
        else:
            phi = tf.where((cosine - self.th) > 0, phi, cosine - self.mm)
        
        # -------------torch.where(out_i = {x_i if condition_i else y_i) -------------
        arc = (y_true * phi) + ((1.0 - y_true) * cosine)  # you can use torch.where if your torch.__version__ is 0.4
        arc *= self.s
        return self.lossfn(y_true,arc)
    
## Main Model ##
class ClassModel(keras.Model):
    def __init__(self,encoder,out_features=10,mode="dense"):
        super().__init__()
        assert mode in ["dense","cosmargin","arcmargin"]
        self.encoder=encoder
        self.mode=mode
        self.latent_features=encoder.latent_features
        
        if self.mode=="dense":
            self.output_layer=keras.layers.Dense(out_features,use_bias=False)
            self.loss_fn=FocalLoss(3)
            return
        
        self.output_layer=CosineLayer(out_features)
        if self.mode=="cosmargin":
            self.loss_fn=AddMarginLoss(s=5,m=0.3)
        if self.mode=="arcmargin":
            self.loss_fn=ArcMarginLoss(s=5,m=0.4,easy_margin=False)
        
    def call(self,x,training=False):
        latent=self.encoder(x)
        return self.output_layer(latent)

class SiameseModel(keras.Model):
    # Mode: dist= euclidean distance
    #       cos = cosine distance
    #       matmult= matric multiplication distance
    def __init__(self,encoder,mode="cos"):
        super().__init__()
        assert mode in ["dist","cos","matmul"]
        self.encoder=encoder
        self.mode=mode
        self.latent_features=encoder.latent_features
        if self.mode=="dist":
            self.matric_fn=EuclideanDist("paired")
        if self.mode=="cos":
            self.matric_fn=CosSim("paired")
        if self.mode=="matmul":
            self.matric_fn=MatMul("paired")
        self.loss_fn=ContrastiveLoss(1,mode=mode)
            
    def call(self,x,training=False):
        latent_s=self.encoder(x[:,0])
        latent_q=self.encoder(x[:,1])

        return self.matric_fn(latent_q,latent_s)     
  
    
class PrototypicalNetworks(keras.Model):
    # Mode: dist= euclidean distance
    #       cos = cosine distance
    #       matmult= matric multiplication distance
    def __init__(self,encoder,mode="cos"):
        super().__init__()
        assert mode in ["dist","cos","matmul","cosmargin","arcmargin"]
        self.encoder=encoder
        self.mode=mode
        self.latent_features=encoder.latent_features
        #Metric function#    
        if mode in ["cos","cosmargin","arcmargin"]:
            self.matric_fn=CosSim("cross")
        if self.mode=="dist":
            self.matric_fn=EuclideanDist("cross")
        if self.mode=="matmul":
            self.matric_fn=MatMul("cross")
        #Loss function, including output activation#
        if mode in ["dist","cos","matmul"]:
            self.loss_fn=FocalLoss(3)
        if self.mode=="cosmargin":
            self.loss_fn=AddMarginLoss(s=5,m=0.3)
        if self.mode=="arcmargin":
            self.loss_fn=ArcMarginLoss(s=5,m=0.4,easy_margin=False)  
            
    def call(self,x,training=False):
        # 計算query latent
        latent_q=tf.stack([self.encoder(x[:,WAYS*SHOTS+ii]) for ii in range(WAYS)],axis=1)        
        
        # 計算 prototypes
        latent_s=[self.encoder(x[:,ii]) for ii in range(WAYS*SHOTS)]
        latent_proto=tf.stack([tf.reduce_mean(tf.stack(latent_s[ww*SHOTS:(ww+1)*SHOTS],axis=-1),axis=-1)
                     for ww in range(WAYS)],axis=1)
        # 計算metric
        return self.matric_fn(latent_q,latent_proto)

# %%
enc=Encoder(n_layers=2,latent_features=2,hidden_featrues=64)
model=PrototypicalNetworks(enc,mode="matmul")# {"dist","cos","matmul","cosmargin","arcmargin"}

# %%
# loss_fn=ArcMarginLoss(s=5,m=0.4,easy_margin=False)
loss_fn=model.loss_fn
opt=keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss=loss_fn, optimizer=opt, metrics=[keras.metrics.CategoricalAccuracy()])

# %%
## Recording Callbacks
class LogLatent(keras.callbacks.Callback):
    def __init__(self,encoder,test_x,test_y,skip_iters=100):
        self.df=self.df=pd.DataFrame()
        self.encoder=encoder
        self.plt_x=test_x
        self.plt_y=test_y
        self.itr=0
        self.skip_iters=skip_iters
    def on_batch_end(self,batch, logs={}):
        if self.itr%self.skip_iters==self.skip_iters-1:
            latent=self.encoder(self.plt_x)
            df_new=pd.DataFrame()
            df_new["f1"]=latent[:,0]
            df_new["f2"]=latent[:,1]
            df_new["arc"]=0.5
            df_new["iterations"]=np.repeat(self.itr,len(latent))

            df_new["label"]=self.plt_y
            self.df=self.df.append(df_new)
        self.itr+=1
    def normalize(self):
        # Normalize latent by maximum value
        self.mx_norm=np.linalg.norm(self.df[["f1","f2"]].values,axis=1).max()
        self.df[["f1",'f2']]=self.df[["f1",'f2']].apply(lambda x: x/self.mx_norm)

        # Project latents into arc
        df=self.df.copy()
        norm=np.linalg.norm(df[["f1","f2"]].values,axis=1,keepdims=True)
        df[["f1",'f2']]=df[["f1",'f2']].values/norm
        df["arc"]=df["arc"].map({0.5:0.9},na_action=None)
        
        self.df=self.df.append(df)

# %%
train_loader = train_meta_loader.shuffle(1000).cache().prefetch(meta_batch_size).batch(meta_batch_size)

val_loader = train_meta_loader.shuffle(1000).cache().prefetch(meta_batch_size*4).batch(meta_batch_size*4)

# %%
lg=LogLatent(enc,plt_x,plt_y)
try:
    model.fit(train_loader, 
              epochs=800,
              validation_data=val_loader,
              callbacks=[lg])
except KeyboardInterrupt:
    print("KeyboardInterrupt")
# Out:
# Epoch 1/800
# 3/3 [==============================] - 190s 46s/step - loss: 0.8209 - categorical_accuracy: 0.2808 - val_loss: 0.8075 - val_categorical_accuracy: 0.2125
# Epoch 2/800
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7891 - categorical_accuracy: 0.2070 - val_loss: 0.7560 - val_categorical_accuracy: 0.2650
# Epoch 3/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.7257 - categorical_accuracy: 0.3178 - val_loss: 0.6482 - val_categorical_accuracy: 0.4650
# Epoch 4/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.6008 - categorical_accuracy: 0.4327 - val_loss: 0.5121 - val_categorical_accuracy: 0.5075
# Epoch 5/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.5668 - categorical_accuracy: 0.4639 - val_loss: 0.4671 - val_categorical_accuracy: 0.5275
# Epoch 6/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.5046 - categorical_accuracy: 0.5037 - val_loss: 0.4642 - val_categorical_accuracy: 0.5450
# Epoch 7/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4787 - categorical_accuracy: 0.5150 - val_loss: 0.4785 - val_categorical_accuracy: 0.5375
# Epoch 8/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4766 - categorical_accuracy: 0.5166 - val_loss: 0.4577 - val_categorical_accuracy: 0.5475
# Epoch 9/800
# 3/3 [==============================] - 0s 73ms/step - loss: 0.4612 - categorical_accuracy: 0.4958 - val_loss: 0.4287 - val_categorical_accuracy: 0.5525
# Epoch 10/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4259 - categorical_accuracy: 0.5492 - val_loss: 0.4106 - val_categorical_accuracy: 0.5425
# Epoch 11/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.4237 - categorical_accuracy: 0.5175 - val_loss: 0.4063 - val_categorical_accuracy: 0.5600
# Epoch 12/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4023 - categorical_accuracy: 0.5520 - val_loss: 0.4041 - val_categorical_accuracy: 0.5575
# Epoch 13/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3839 - categorical_accuracy: 0.5691 - val_loss: 0.3961 - val_categorical_accuracy: 0.5525
# Epoch 14/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3845 - categorical_accuracy: 0.5389 - val_loss: 0.3811 - val_categorical_accuracy: 0.5575
# Epoch 15/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3826 - categorical_accuracy: 0.5784 - val_loss: 0.3664 - val_categorical_accuracy: 0.5725
# Epoch 16/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.3659 - categorical_accuracy: 0.5844 - val_loss: 0.3526 - val_categorical_accuracy: 0.5875
# Epoch 17/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3334 - categorical_accuracy: 0.6028 - val_loss: 0.3401 - val_categorical_accuracy: 0.6025
# Epoch 18/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3271 - categorical_accuracy: 0.5994 - val_loss: 0.3299 - val_categorical_accuracy: 0.6125
# Epoch 19/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.3376 - categorical_accuracy: 0.5988 - val_loss: 0.3173 - val_categorical_accuracy: 0.6350
# Epoch 20/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3016 - categorical_accuracy: 0.6311 - val_loss: 0.3151 - val_categorical_accuracy: 0.6300
# Epoch 21/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.2946 - categorical_accuracy: 0.6338 - val_loss: 0.2980 - val_categorical_accuracy: 0.6450
# Epoch 22/800
# 3/3 [==============================] - 0s 74ms/step - loss: 0.2910 - categorical_accuracy: 0.6378 - val_loss: 0.2990 - val_categorical_accuracy: 0.6500
# Epoch 23/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2740 - categorical_accuracy: 0.6542 - val_loss: 0.2812 - val_categorical_accuracy: 0.6450
# Epoch 24/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2575 - categorical_accuracy: 0.6355 - val_loss: 0.2747 - val_categorical_accuracy: 0.6525
# Epoch 25/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2449 - categorical_accuracy: 0.6587 - val_loss: 0.2668 - val_categorical_accuracy: 0.6675
# Epoch 26/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2346 - categorical_accuracy: 0.6689 - val_loss: 0.2562 - val_categorical_accuracy: 0.6775
# Epoch 27/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2324 - categorical_accuracy: 0.6998 - val_loss: 0.2499 - val_categorical_accuracy: 0.6850
# Epoch 28/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2112 - categorical_accuracy: 0.6836 - val_loss: 0.2408 - val_categorical_accuracy: 0.6975
# Epoch 29/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1979 - categorical_accuracy: 0.7111 - val_loss: 0.2435 - val_categorical_accuracy: 0.7000
# Epoch 30/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2103 - categorical_accuracy: 0.6963 - val_loss: 0.2305 - val_categorical_accuracy: 0.7100
# Epoch 31/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1896 - categorical_accuracy: 0.7089 - val_loss: 0.2257 - val_categorical_accuracy: 0.7075
# Epoch 32/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1919 - categorical_accuracy: 0.7169 - val_loss: 0.2224 - val_categorical_accuracy: 0.7050
# Epoch 33/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1966 - categorical_accuracy: 0.6997 - val_loss: 0.2249 - val_categorical_accuracy: 0.7000
# Epoch 34/800
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1803 - categorical_accuracy: 0.7075 - val_loss: 0.2200 - val_categorical_accuracy: 0.6950
# Epoch 35/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1792 - categorical_accuracy: 0.7161 - val_loss: 0.2237 - val_categorical_accuracy: 0.7050
# Epoch 36/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1737 - categorical_accuracy: 0.7291 - val_loss: 0.2170 - val_categorical_accuracy: 0.7025
# Epoch 37/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1706 - categorical_accuracy: 0.7409 - val_loss: 0.2174 - val_categorical_accuracy: 0.7025
# Epoch 38/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1731 - categorical_accuracy: 0.7258 - val_loss: 0.2097 - val_categorical_accuracy: 0.7075
# Epoch 39/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1601 - categorical_accuracy: 0.7492 - val_loss: 0.2091 - val_categorical_accuracy: 0.7050
# Epoch 40/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1484 - categorical_accuracy: 0.7497 - val_loss: 0.2051 - val_categorical_accuracy: 0.7100
# Epoch 41/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1566 - categorical_accuracy: 0.7464 - val_loss: 0.2054 - val_categorical_accuracy: 0.7125
# Epoch 42/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1510 - categorical_accuracy: 0.7522 - val_loss: 0.2122 - val_categorical_accuracy: 0.7150
# Epoch 43/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1584 - categorical_accuracy: 0.7788 - val_loss: 0.2038 - val_categorical_accuracy: 0.7175
# Epoch 44/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1457 - categorical_accuracy: 0.7477 - val_loss: 0.2075 - val_categorical_accuracy: 0.7200
# Epoch 45/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1396 - categorical_accuracy: 0.7519 - val_loss: 0.2064 - val_categorical_accuracy: 0.7150
# Epoch 46/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1508 - categorical_accuracy: 0.7548 - val_loss: 0.2150 - val_categorical_accuracy: 0.7250
# Epoch 47/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1369 - categorical_accuracy: 0.7666 - val_loss: 0.2052 - val_categorical_accuracy: 0.7100
# Epoch 48/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1426 - categorical_accuracy: 0.7531 - val_loss: 0.2033 - val_categorical_accuracy: 0.7125
# Epoch 49/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1241 - categorical_accuracy: 0.7823 - val_loss: 0.2130 - val_categorical_accuracy: 0.7200
# Epoch 50/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1478 - categorical_accuracy: 0.7364 - val_loss: 0.1984 - val_categorical_accuracy: 0.7100
# Epoch 51/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1334 - categorical_accuracy: 0.7680 - val_loss: 0.2110 - val_categorical_accuracy: 0.7250
# Epoch 52/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1267 - categorical_accuracy: 0.7523 - val_loss: 0.2014 - val_categorical_accuracy: 0.7075
# Epoch 53/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1344 - categorical_accuracy: 0.7738 - val_loss: 0.1961 - val_categorical_accuracy: 0.7075
# Epoch 54/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1193 - categorical_accuracy: 0.7902 - val_loss: 0.2121 - val_categorical_accuracy: 0.7275
# Epoch 55/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1261 - categorical_accuracy: 0.7889 - val_loss: 0.2102 - val_categorical_accuracy: 0.7200
# Epoch 56/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1190 - categorical_accuracy: 0.7747 - val_loss: 0.2179 - val_categorical_accuracy: 0.7250
# Epoch 57/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1331 - categorical_accuracy: 0.7478 - val_loss: 0.1985 - val_categorical_accuracy: 0.7050
# Epoch 58/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1153 - categorical_accuracy: 0.7570 - val_loss: 0.2108 - val_categorical_accuracy: 0.7200
# Epoch 59/800
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1193 - categorical_accuracy: 0.7877 - val_loss: 0.2079 - val_categorical_accuracy: 0.7275
# Epoch 60/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1238 - categorical_accuracy: 0.7573 - val_loss: 0.1955 - val_categorical_accuracy: 0.7100
# Epoch 61/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1266 - categorical_accuracy: 0.7717 - val_loss: 0.2176 - val_categorical_accuracy: 0.7200
# Epoch 62/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1233 - categorical_accuracy: 0.7795 - val_loss: 0.1991 - val_categorical_accuracy: 0.7225
# Epoch 63/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1119 - categorical_accuracy: 0.7894 - val_loss: 0.1997 - val_categorical_accuracy: 0.7000
# Epoch 64/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1116 - categorical_accuracy: 0.7994 - val_loss: 0.2266 - val_categorical_accuracy: 0.7150
# Epoch 65/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1158 - categorical_accuracy: 0.7650 - val_loss: 0.2059 - val_categorical_accuracy: 0.7100
# Epoch 66/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1172 - categorical_accuracy: 0.7911 - val_loss: 0.2043 - val_categorical_accuracy: 0.7100
# Epoch 67/800
# 3/3 [==============================] - 0s 75ms/step - loss: 0.1044 - categorical_accuracy: 0.7884 - val_loss: 0.2155 - val_categorical_accuracy: 0.7075
# Epoch 68/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1209 - categorical_accuracy: 0.7791 - val_loss: 0.2044 - val_categorical_accuracy: 0.7150
# Epoch 69/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1022 - categorical_accuracy: 0.8072 - val_loss: 0.2038 - val_categorical_accuracy: 0.7250
# Epoch 70/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1047 - categorical_accuracy: 0.8056 - val_loss: 0.2067 - val_categorical_accuracy: 0.7125
# Epoch 71/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0985 - categorical_accuracy: 0.8050 - val_loss: 0.2104 - val_categorical_accuracy: 0.7000
# Epoch 72/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0957 - categorical_accuracy: 0.8062 - val_loss: 0.2098 - val_categorical_accuracy: 0.7225
# Epoch 73/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1068 - categorical_accuracy: 0.7945 - val_loss: 0.2120 - val_categorical_accuracy: 0.7075
# Epoch 74/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1138 - categorical_accuracy: 0.7844 - val_loss: 0.2064 - val_categorical_accuracy: 0.7175
# Epoch 75/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0866 - categorical_accuracy: 0.8194 - val_loss: 0.2146 - val_categorical_accuracy: 0.7200
# Epoch 76/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0887 - categorical_accuracy: 0.8191 - val_loss: 0.2065 - val_categorical_accuracy: 0.7175
# Epoch 77/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.1099 - categorical_accuracy: 0.7995 - val_loss: 0.2267 - val_categorical_accuracy: 0.7100
# Epoch 78/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1059 - categorical_accuracy: 0.7775 - val_loss: 0.2114 - val_categorical_accuracy: 0.7225
# Epoch 79/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0945 - categorical_accuracy: 0.8125 - val_loss: 0.2004 - val_categorical_accuracy: 0.7225
# Epoch 80/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1027 - categorical_accuracy: 0.7997 - val_loss: 0.2197 - val_categorical_accuracy: 0.7225
# Epoch 81/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0962 - categorical_accuracy: 0.8206 - val_loss: 0.2083 - val_categorical_accuracy: 0.7075
# Epoch 82/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0972 - categorical_accuracy: 0.8033 - val_loss: 0.2226 - val_categorical_accuracy: 0.7200
# Epoch 83/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0926 - categorical_accuracy: 0.8134 - val_loss: 0.2034 - val_categorical_accuracy: 0.7150
# Epoch 84/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0844 - categorical_accuracy: 0.8152 - val_loss: 0.2079 - val_categorical_accuracy: 0.7175
# Epoch 85/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0998 - categorical_accuracy: 0.8108 - val_loss: 0.2287 - val_categorical_accuracy: 0.7275
# Epoch 86/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0958 - categorical_accuracy: 0.8020 - val_loss: 0.2033 - val_categorical_accuracy: 0.7075
# Epoch 87/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0953 - categorical_accuracy: 0.8080 - val_loss: 0.2132 - val_categorical_accuracy: 0.7250
# Epoch 88/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0898 - categorical_accuracy: 0.8086 - val_loss: 0.2227 - val_categorical_accuracy: 0.7325
# Epoch 89/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0882 - categorical_accuracy: 0.8242 - val_loss: 0.2065 - val_categorical_accuracy: 0.7075
# Epoch 90/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0970 - categorical_accuracy: 0.8292 - val_loss: 0.2086 - val_categorical_accuracy: 0.7300
# Epoch 91/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0878 - categorical_accuracy: 0.8173 - val_loss: 0.2345 - val_categorical_accuracy: 0.7200
# Epoch 92/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0874 - categorical_accuracy: 0.8331 - val_loss: 0.2106 - val_categorical_accuracy: 0.7325
# Epoch 93/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0844 - categorical_accuracy: 0.8094 - val_loss: 0.2133 - val_categorical_accuracy: 0.7275
# Epoch 94/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0843 - categorical_accuracy: 0.8172 - val_loss: 0.2095 - val_categorical_accuracy: 0.7325
# Epoch 95/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0809 - categorical_accuracy: 0.8292 - val_loss: 0.2056 - val_categorical_accuracy: 0.7150
# Epoch 96/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0815 - categorical_accuracy: 0.8172 - val_loss: 0.2242 - val_categorical_accuracy: 0.7200
# Epoch 97/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0751 - categorical_accuracy: 0.8295 - val_loss: 0.2398 - val_categorical_accuracy: 0.7200
# Epoch 98/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0853 - categorical_accuracy: 0.8183 - val_loss: 0.2199 - val_categorical_accuracy: 0.7125
# Epoch 99/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0727 - categorical_accuracy: 0.8211 - val_loss: 0.2256 - val_categorical_accuracy: 0.7225
# Epoch 100/800
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0881 - categorical_accuracy: 0.8305 - val_loss: 0.2186 - val_categorical_accuracy: 0.7375
# Epoch 101/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0771 - categorical_accuracy: 0.8280 - val_loss: 0.2031 - val_categorical_accuracy: 0.7275
# Epoch 102/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0770 - categorical_accuracy: 0.8531 - val_loss: 0.2148 - val_categorical_accuracy: 0.7125
# Epoch 103/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0702 - categorical_accuracy: 0.8498 - val_loss: 0.2233 - val_categorical_accuracy: 0.7125
# Epoch 104/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0691 - categorical_accuracy: 0.8356 - val_loss: 0.2153 - val_categorical_accuracy: 0.7250
# Epoch 105/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0799 - categorical_accuracy: 0.8366 - val_loss: 0.2254 - val_categorical_accuracy: 0.7375
# Epoch 106/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0659 - categorical_accuracy: 0.8475 - val_loss: 0.2273 - val_categorical_accuracy: 0.7425
# Epoch 107/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0774 - categorical_accuracy: 0.8361 - val_loss: 0.2181 - val_categorical_accuracy: 0.7200
# Epoch 108/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0676 - categorical_accuracy: 0.8523 - val_loss: 0.2340 - val_categorical_accuracy: 0.7350
# Epoch 109/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0734 - categorical_accuracy: 0.8522 - val_loss: 0.2256 - val_categorical_accuracy: 0.7350
# Epoch 110/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0679 - categorical_accuracy: 0.8347 - val_loss: 0.2343 - val_categorical_accuracy: 0.7275
# Epoch 111/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0781 - categorical_accuracy: 0.8270 - val_loss: 0.2095 - val_categorical_accuracy: 0.7200
# Epoch 112/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0695 - categorical_accuracy: 0.8536 - val_loss: 0.2122 - val_categorical_accuracy: 0.7225
# Epoch 113/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0706 - categorical_accuracy: 0.8539 - val_loss: 0.2152 - val_categorical_accuracy: 0.7375
# Epoch 114/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0696 - categorical_accuracy: 0.8623 - val_loss: 0.2029 - val_categorical_accuracy: 0.7250
# Epoch 115/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0696 - categorical_accuracy: 0.8572 - val_loss: 0.2128 - val_categorical_accuracy: 0.7275
# Epoch 116/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0702 - categorical_accuracy: 0.8588 - val_loss: 0.2209 - val_categorical_accuracy: 0.7300
# Epoch 117/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0614 - categorical_accuracy: 0.8584 - val_loss: 0.2326 - val_categorical_accuracy: 0.7325
# Epoch 118/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0827 - categorical_accuracy: 0.8422 - val_loss: 0.2245 - val_categorical_accuracy: 0.7100
# Epoch 119/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0632 - categorical_accuracy: 0.8655 - val_loss: 0.2139 - val_categorical_accuracy: 0.7100
# Epoch 120/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0604 - categorical_accuracy: 0.8781 - val_loss: 0.2304 - val_categorical_accuracy: 0.7225
# Epoch 121/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0626 - categorical_accuracy: 0.8692 - val_loss: 0.2137 - val_categorical_accuracy: 0.7200
# Epoch 122/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0665 - categorical_accuracy: 0.8516 - val_loss: 0.2303 - val_categorical_accuracy: 0.7100
# Epoch 123/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0683 - categorical_accuracy: 0.8450 - val_loss: 0.2446 - val_categorical_accuracy: 0.7225
# Epoch 124/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0560 - categorical_accuracy: 0.8720 - val_loss: 0.2296 - val_categorical_accuracy: 0.7350
# Epoch 125/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0746 - categorical_accuracy: 0.8448 - val_loss: 0.2284 - val_categorical_accuracy: 0.7175
# Epoch 126/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0704 - categorical_accuracy: 0.8466 - val_loss: 0.2219 - val_categorical_accuracy: 0.7175
# Epoch 127/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0588 - categorical_accuracy: 0.8886 - val_loss: 0.2153 - val_categorical_accuracy: 0.7150
# Epoch 128/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0618 - categorical_accuracy: 0.8555 - val_loss: 0.2173 - val_categorical_accuracy: 0.7125
# Epoch 129/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0646 - categorical_accuracy: 0.8627 - val_loss: 0.2179 - val_categorical_accuracy: 0.7200
# Epoch 130/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0601 - categorical_accuracy: 0.8606 - val_loss: 0.2126 - val_categorical_accuracy: 0.7325
# Epoch 131/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0645 - categorical_accuracy: 0.8606 - val_loss: 0.2344 - val_categorical_accuracy: 0.7175
# Epoch 132/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0588 - categorical_accuracy: 0.8720 - val_loss: 0.2217 - val_categorical_accuracy: 0.7050
# Epoch 133/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0523 - categorical_accuracy: 0.8703 - val_loss: 0.2219 - val_categorical_accuracy: 0.7050
# Epoch 134/800
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0654 - categorical_accuracy: 0.8536 - val_loss: 0.2536 - val_categorical_accuracy: 0.7075
# Epoch 135/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0854 - categorical_accuracy: 0.8427 - val_loss: 0.2205 - val_categorical_accuracy: 0.7000
# Epoch 136/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0797 - categorical_accuracy: 0.8277 - val_loss: 0.2284 - val_categorical_accuracy: 0.7175
# Epoch 137/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0618 - categorical_accuracy: 0.8506 - val_loss: 0.2298 - val_categorical_accuracy: 0.7125
# Epoch 138/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0644 - categorical_accuracy: 0.8553 - val_loss: 0.2141 - val_categorical_accuracy: 0.7075
# Epoch 139/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0680 - categorical_accuracy: 0.8564 - val_loss: 0.2294 - val_categorical_accuracy: 0.7275
# Epoch 140/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0593 - categorical_accuracy: 0.8713 - val_loss: 0.2483 - val_categorical_accuracy: 0.7100
# Epoch 141/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0599 - categorical_accuracy: 0.8877 - val_loss: 0.2292 - val_categorical_accuracy: 0.7275
# Epoch 142/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0529 - categorical_accuracy: 0.8713 - val_loss: 0.2277 - val_categorical_accuracy: 0.7250
# Epoch 143/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0670 - categorical_accuracy: 0.8569 - val_loss: 0.2358 - val_categorical_accuracy: 0.7375
# Epoch 144/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0584 - categorical_accuracy: 0.8655 - val_loss: 0.2401 - val_categorical_accuracy: 0.7050
# Epoch 145/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0521 - categorical_accuracy: 0.8514 - val_loss: 0.2392 - val_categorical_accuracy: 0.7050
# Epoch 146/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0561 - categorical_accuracy: 0.8528 - val_loss: 0.2271 - val_categorical_accuracy: 0.7150
# Epoch 147/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0589 - categorical_accuracy: 0.8820 - val_loss: 0.2234 - val_categorical_accuracy: 0.7125
# Epoch 148/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0660 - categorical_accuracy: 0.8678 - val_loss: 0.2435 - val_categorical_accuracy: 0.7000
# Epoch 149/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0612 - categorical_accuracy: 0.8658 - val_loss: 0.2191 - val_categorical_accuracy: 0.7100
# Epoch 150/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0486 - categorical_accuracy: 0.8783 - val_loss: 0.2079 - val_categorical_accuracy: 0.7100
# Epoch 151/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0580 - categorical_accuracy: 0.8667 - val_loss: 0.2281 - val_categorical_accuracy: 0.7275
# Epoch 152/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0584 - categorical_accuracy: 0.8463 - val_loss: 0.2276 - val_categorical_accuracy: 0.7150
# Epoch 153/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0492 - categorical_accuracy: 0.8706 - val_loss: 0.2414 - val_categorical_accuracy: 0.7025
# Epoch 154/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0572 - categorical_accuracy: 0.8861 - val_loss: 0.2398 - val_categorical_accuracy: 0.7200
# Epoch 155/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0499 - categorical_accuracy: 0.8847 - val_loss: 0.2606 - val_categorical_accuracy: 0.7225
# Epoch 156/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0553 - categorical_accuracy: 0.8877 - val_loss: 0.2321 - val_categorical_accuracy: 0.7250
# Epoch 157/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0544 - categorical_accuracy: 0.8716 - val_loss: 0.2299 - val_categorical_accuracy: 0.7050
# Epoch 158/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0581 - categorical_accuracy: 0.8708 - val_loss: 0.2242 - val_categorical_accuracy: 0.7175
# Epoch 159/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0482 - categorical_accuracy: 0.8964 - val_loss: 0.2265 - val_categorical_accuracy: 0.7275
# Epoch 160/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0524 - categorical_accuracy: 0.8784 - val_loss: 0.2215 - val_categorical_accuracy: 0.7175
# Epoch 161/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0511 - categorical_accuracy: 0.8897 - val_loss: 0.2441 - val_categorical_accuracy: 0.7200
# Epoch 162/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0520 - categorical_accuracy: 0.8725 - val_loss: 0.2352 - val_categorical_accuracy: 0.7200
# Epoch 163/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0492 - categorical_accuracy: 0.8748 - val_loss: 0.2224 - val_categorical_accuracy: 0.7275
# Epoch 164/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0496 - categorical_accuracy: 0.8770 - val_loss: 0.2254 - val_categorical_accuracy: 0.7325
# Epoch 165/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0440 - categorical_accuracy: 0.9000 - val_loss: 0.2444 - val_categorical_accuracy: 0.7100
# Epoch 166/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0503 - categorical_accuracy: 0.8831 - val_loss: 0.2433 - val_categorical_accuracy: 0.7125
# Epoch 167/800
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0535 - categorical_accuracy: 0.8814 - val_loss: 0.2457 - val_categorical_accuracy: 0.7350
# Epoch 168/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0530 - categorical_accuracy: 0.9050 - val_loss: 0.2399 - val_categorical_accuracy: 0.7325
# Epoch 169/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0473 - categorical_accuracy: 0.8711 - val_loss: 0.2355 - val_categorical_accuracy: 0.7100
# Epoch 170/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0426 - categorical_accuracy: 0.8833 - val_loss: 0.2506 - val_categorical_accuracy: 0.7175
# Epoch 171/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0569 - categorical_accuracy: 0.8561 - val_loss: 0.2371 - val_categorical_accuracy: 0.7100
# Epoch 172/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0528 - categorical_accuracy: 0.8937 - val_loss: 0.2690 - val_categorical_accuracy: 0.6975
# Epoch 173/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0493 - categorical_accuracy: 0.8841 - val_loss: 0.2419 - val_categorical_accuracy: 0.7175
# Epoch 174/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0426 - categorical_accuracy: 0.8892 - val_loss: 0.2333 - val_categorical_accuracy: 0.7200
# Epoch 175/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0417 - categorical_accuracy: 0.8872 - val_loss: 0.2415 - val_categorical_accuracy: 0.7275
# Epoch 176/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0478 - categorical_accuracy: 0.9070 - val_loss: 0.2267 - val_categorical_accuracy: 0.7250
# Epoch 177/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0531 - categorical_accuracy: 0.8841 - val_loss: 0.2340 - val_categorical_accuracy: 0.7300
# Epoch 178/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0455 - categorical_accuracy: 0.8777 - val_loss: 0.2412 - val_categorical_accuracy: 0.7250
# Epoch 179/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0423 - categorical_accuracy: 0.8905 - val_loss: 0.2334 - val_categorical_accuracy: 0.7225
# Epoch 180/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0494 - categorical_accuracy: 0.8787 - val_loss: 0.2411 - val_categorical_accuracy: 0.7300
# Epoch 181/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0431 - categorical_accuracy: 0.8853 - val_loss: 0.2389 - val_categorical_accuracy: 0.7125
# Epoch 182/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0458 - categorical_accuracy: 0.9081 - val_loss: 0.2338 - val_categorical_accuracy: 0.7175
# Epoch 183/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0491 - categorical_accuracy: 0.8880 - val_loss: 0.2271 - val_categorical_accuracy: 0.7125
# Epoch 184/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0510 - categorical_accuracy: 0.8889 - val_loss: 0.2464 - val_categorical_accuracy: 0.7075
# Epoch 185/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0430 - categorical_accuracy: 0.8973 - val_loss: 0.2400 - val_categorical_accuracy: 0.7100
# Epoch 186/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0425 - categorical_accuracy: 0.9048 - val_loss: 0.2260 - val_categorical_accuracy: 0.7125
# Epoch 187/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0450 - categorical_accuracy: 0.8917 - val_loss: 0.2559 - val_categorical_accuracy: 0.7175
# Epoch 188/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0431 - categorical_accuracy: 0.9067 - val_loss: 0.2531 - val_categorical_accuracy: 0.7250
# Epoch 189/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0484 - categorical_accuracy: 0.8856 - val_loss: 0.2448 - val_categorical_accuracy: 0.7125
# Epoch 190/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0476 - categorical_accuracy: 0.8627 - val_loss: 0.2527 - val_categorical_accuracy: 0.7100
# Epoch 191/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0429 - categorical_accuracy: 0.9075 - val_loss: 0.2262 - val_categorical_accuracy: 0.7250
# Epoch 192/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0454 - categorical_accuracy: 0.8989 - val_loss: 0.2264 - val_categorical_accuracy: 0.7175
# Epoch 193/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0399 - categorical_accuracy: 0.9014 - val_loss: 0.2509 - val_categorical_accuracy: 0.7050
# Epoch 194/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0395 - categorical_accuracy: 0.9064 - val_loss: 0.2629 - val_categorical_accuracy: 0.7025
# Epoch 195/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0369 - categorical_accuracy: 0.9097 - val_loss: 0.2510 - val_categorical_accuracy: 0.7125
# Epoch 196/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0489 - categorical_accuracy: 0.8852 - val_loss: 0.2437 - val_categorical_accuracy: 0.7200
# Epoch 197/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0444 - categorical_accuracy: 0.9094 - val_loss: 0.2554 - val_categorical_accuracy: 0.7050
# Epoch 198/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0398 - categorical_accuracy: 0.9042 - val_loss: 0.2262 - val_categorical_accuracy: 0.7225
# Epoch 199/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0433 - categorical_accuracy: 0.8922 - val_loss: 0.2221 - val_categorical_accuracy: 0.7300
# Epoch 200/800
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0408 - categorical_accuracy: 0.8906 - val_loss: 0.2647 - val_categorical_accuracy: 0.7225
# Epoch 201/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0436 - categorical_accuracy: 0.8880 - val_loss: 0.2491 - val_categorical_accuracy: 0.7150
# Epoch 202/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0333 - categorical_accuracy: 0.9216 - val_loss: 0.2457 - val_categorical_accuracy: 0.7050
# Epoch 203/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0416 - categorical_accuracy: 0.9052 - val_loss: 0.2705 - val_categorical_accuracy: 0.7000
# Epoch 204/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0483 - categorical_accuracy: 0.8967 - val_loss: 0.2900 - val_categorical_accuracy: 0.6925
# Epoch 205/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0420 - categorical_accuracy: 0.8922 - val_loss: 0.2482 - val_categorical_accuracy: 0.7100
# Epoch 206/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0287 - categorical_accuracy: 0.9330 - val_loss: 0.2424 - val_categorical_accuracy: 0.7075
# Epoch 207/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0378 - categorical_accuracy: 0.9183 - val_loss: 0.2605 - val_categorical_accuracy: 0.7250
# Epoch 208/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0377 - categorical_accuracy: 0.9225 - val_loss: 0.2375 - val_categorical_accuracy: 0.7200
# Epoch 209/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0402 - categorical_accuracy: 0.9002 - val_loss: 0.2537 - val_categorical_accuracy: 0.7175
# Epoch 210/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0378 - categorical_accuracy: 0.9134 - val_loss: 0.2644 - val_categorical_accuracy: 0.7075
# Epoch 211/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0354 - categorical_accuracy: 0.8984 - val_loss: 0.2594 - val_categorical_accuracy: 0.7250
# Epoch 212/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0478 - categorical_accuracy: 0.8872 - val_loss: 0.2515 - val_categorical_accuracy: 0.7125
# Epoch 213/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0279 - categorical_accuracy: 0.9369 - val_loss: 0.2535 - val_categorical_accuracy: 0.7125
# Epoch 214/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0367 - categorical_accuracy: 0.9142 - val_loss: 0.2564 - val_categorical_accuracy: 0.7075
# Epoch 215/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0442 - categorical_accuracy: 0.8980 - val_loss: 0.2411 - val_categorical_accuracy: 0.7175
# Epoch 216/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0325 - categorical_accuracy: 0.9319 - val_loss: 0.2378 - val_categorical_accuracy: 0.7275
# Epoch 217/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0317 - categorical_accuracy: 0.9134 - val_loss: 0.2411 - val_categorical_accuracy: 0.7225
# Epoch 218/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0282 - categorical_accuracy: 0.9348 - val_loss: 0.2593 - val_categorical_accuracy: 0.7175
# Epoch 219/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0292 - categorical_accuracy: 0.9219 - val_loss: 0.2839 - val_categorical_accuracy: 0.7175
# Epoch 220/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0358 - categorical_accuracy: 0.9211 - val_loss: 0.2984 - val_categorical_accuracy: 0.7175
# Epoch 221/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0408 - categorical_accuracy: 0.9144 - val_loss: 0.2785 - val_categorical_accuracy: 0.7100
# Epoch 222/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0393 - categorical_accuracy: 0.9188 - val_loss: 0.2803 - val_categorical_accuracy: 0.7075
# Epoch 223/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0339 - categorical_accuracy: 0.9238 - val_loss: 0.2718 - val_categorical_accuracy: 0.6975
# Epoch 224/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0382 - categorical_accuracy: 0.9167 - val_loss: 0.2546 - val_categorical_accuracy: 0.7050
# Epoch 225/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0363 - categorical_accuracy: 0.9255 - val_loss: 0.2430 - val_categorical_accuracy: 0.7150
# Epoch 226/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0337 - categorical_accuracy: 0.9145 - val_loss: 0.2403 - val_categorical_accuracy: 0.7175
# Epoch 227/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0333 - categorical_accuracy: 0.9164 - val_loss: 0.2584 - val_categorical_accuracy: 0.7125
# Epoch 228/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0296 - categorical_accuracy: 0.9272 - val_loss: 0.2544 - val_categorical_accuracy: 0.7200
# Epoch 229/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0323 - categorical_accuracy: 0.9147 - val_loss: 0.2530 - val_categorical_accuracy: 0.7200
# Epoch 230/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0351 - categorical_accuracy: 0.9333 - val_loss: 0.2562 - val_categorical_accuracy: 0.7125
# Epoch 231/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0383 - categorical_accuracy: 0.8998 - val_loss: 0.2834 - val_categorical_accuracy: 0.7125
# Epoch 232/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0297 - categorical_accuracy: 0.9183 - val_loss: 0.2502 - val_categorical_accuracy: 0.7125
# Epoch 233/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0455 - categorical_accuracy: 0.9108 - val_loss: 0.2446 - val_categorical_accuracy: 0.7150
# Epoch 234/800
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0343 - categorical_accuracy: 0.9217 - val_loss: 0.2612 - val_categorical_accuracy: 0.7200
# Epoch 235/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0401 - categorical_accuracy: 0.9055 - val_loss: 0.2460 - val_categorical_accuracy: 0.7200
# Epoch 236/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0381 - categorical_accuracy: 0.9106 - val_loss: 0.2494 - val_categorical_accuracy: 0.7025
# Epoch 237/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0356 - categorical_accuracy: 0.9086 - val_loss: 0.2518 - val_categorical_accuracy: 0.7050
# Epoch 238/800
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0321 - categorical_accuracy: 0.9194 - val_loss: 0.2583 - val_categorical_accuracy: 0.7275
# Epoch 239/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0308 - categorical_accuracy: 0.9164 - val_loss: 0.2568 - val_categorical_accuracy: 0.7125
# Epoch 240/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0372 - categorical_accuracy: 0.9095 - val_loss: 0.2843 - val_categorical_accuracy: 0.7050
# Epoch 241/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0307 - categorical_accuracy: 0.9177 - val_loss: 0.2580 - val_categorical_accuracy: 0.7125
# Epoch 242/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0269 - categorical_accuracy: 0.9281 - val_loss: 0.2568 - val_categorical_accuracy: 0.7200
# Epoch 243/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0354 - categorical_accuracy: 0.9219 - val_loss: 0.2924 - val_categorical_accuracy: 0.7075
# Epoch 244/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0319 - categorical_accuracy: 0.9272 - val_loss: 0.2671 - val_categorical_accuracy: 0.7000
# Epoch 245/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0327 - categorical_accuracy: 0.9233 - val_loss: 0.2523 - val_categorical_accuracy: 0.7200
# Epoch 246/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0301 - categorical_accuracy: 0.9344 - val_loss: 0.2598 - val_categorical_accuracy: 0.7200
# Epoch 247/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0249 - categorical_accuracy: 0.9211 - val_loss: 0.2702 - val_categorical_accuracy: 0.7275
# Epoch 248/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0301 - categorical_accuracy: 0.9173 - val_loss: 0.2663 - val_categorical_accuracy: 0.7200
# Epoch 249/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0321 - categorical_accuracy: 0.9370 - val_loss: 0.2686 - val_categorical_accuracy: 0.7125
# Epoch 250/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0260 - categorical_accuracy: 0.9339 - val_loss: 0.2701 - val_categorical_accuracy: 0.7175
# Epoch 251/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0356 - categorical_accuracy: 0.9225 - val_loss: 0.2810 - val_categorical_accuracy: 0.7000
# Epoch 252/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0292 - categorical_accuracy: 0.9452 - val_loss: 0.2949 - val_categorical_accuracy: 0.7025
# Epoch 253/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0340 - categorical_accuracy: 0.9098 - val_loss: 0.2544 - val_categorical_accuracy: 0.7050
# Epoch 254/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0306 - categorical_accuracy: 0.9216 - val_loss: 0.2502 - val_categorical_accuracy: 0.7150
# Epoch 255/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0312 - categorical_accuracy: 0.9122 - val_loss: 0.2597 - val_categorical_accuracy: 0.7225
# Epoch 256/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0298 - categorical_accuracy: 0.9416 - val_loss: 0.2669 - val_categorical_accuracy: 0.6950
# Epoch 257/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0222 - categorical_accuracy: 0.9473 - val_loss: 0.2655 - val_categorical_accuracy: 0.7000
# Epoch 258/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0302 - categorical_accuracy: 0.9295 - val_loss: 0.2826 - val_categorical_accuracy: 0.7175
# Epoch 259/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0276 - categorical_accuracy: 0.9152 - val_loss: 0.2859 - val_categorical_accuracy: 0.7150
# Epoch 260/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0280 - categorical_accuracy: 0.9423 - val_loss: 0.2597 - val_categorical_accuracy: 0.7125
# Epoch 261/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0338 - categorical_accuracy: 0.9138 - val_loss: 0.2645 - val_categorical_accuracy: 0.7150
# Epoch 262/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0412 - categorical_accuracy: 0.9134 - val_loss: 0.2878 - val_categorical_accuracy: 0.7000
# Epoch 263/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0385 - categorical_accuracy: 0.9123 - val_loss: 0.2450 - val_categorical_accuracy: 0.7175
# Epoch 264/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0238 - categorical_accuracy: 0.9436 - val_loss: 0.2472 - val_categorical_accuracy: 0.7150
# Epoch 265/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0315 - categorical_accuracy: 0.9323 - val_loss: 0.2774 - val_categorical_accuracy: 0.7175
# Epoch 266/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0325 - categorical_accuracy: 0.9248 - val_loss: 0.2841 - val_categorical_accuracy: 0.7050
# Epoch 267/800
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0253 - categorical_accuracy: 0.9370 - val_loss: 0.2499 - val_categorical_accuracy: 0.7225
# Epoch 268/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0337 - categorical_accuracy: 0.9266 - val_loss: 0.2552 - val_categorical_accuracy: 0.7100
# Epoch 269/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0337 - categorical_accuracy: 0.9206 - val_loss: 0.2611 - val_categorical_accuracy: 0.7200
# Epoch 270/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0289 - categorical_accuracy: 0.9306 - val_loss: 0.2461 - val_categorical_accuracy: 0.7225
# Epoch 271/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0399 - categorical_accuracy: 0.9141 - val_loss: 0.2390 - val_categorical_accuracy: 0.7125
# Epoch 272/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0308 - categorical_accuracy: 0.9252 - val_loss: 0.2539 - val_categorical_accuracy: 0.7100
# Epoch 273/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0299 - categorical_accuracy: 0.9284 - val_loss: 0.2870 - val_categorical_accuracy: 0.6925
# Epoch 274/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0303 - categorical_accuracy: 0.9227 - val_loss: 0.2586 - val_categorical_accuracy: 0.7175
# Epoch 275/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0300 - categorical_accuracy: 0.9139 - val_loss: 0.2495 - val_categorical_accuracy: 0.7150
# Epoch 276/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0279 - categorical_accuracy: 0.9253 - val_loss: 0.2600 - val_categorical_accuracy: 0.7050
# Epoch 277/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0256 - categorical_accuracy: 0.9548 - val_loss: 0.2862 - val_categorical_accuracy: 0.7200
# Epoch 278/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0356 - categorical_accuracy: 0.9036 - val_loss: 0.2591 - val_categorical_accuracy: 0.7175
# Epoch 279/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0313 - categorical_accuracy: 0.9188 - val_loss: 0.2625 - val_categorical_accuracy: 0.7050
# Epoch 280/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0336 - categorical_accuracy: 0.9417 - val_loss: 0.2982 - val_categorical_accuracy: 0.6925
# Epoch 281/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0284 - categorical_accuracy: 0.9370 - val_loss: 0.3014 - val_categorical_accuracy: 0.7125
# Epoch 282/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0331 - categorical_accuracy: 0.9359 - val_loss: 0.2636 - val_categorical_accuracy: 0.7125
# Epoch 283/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0387 - categorical_accuracy: 0.9278 - val_loss: 0.2524 - val_categorical_accuracy: 0.7100
# Epoch 284/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0247 - categorical_accuracy: 0.9420 - val_loss: 0.2576 - val_categorical_accuracy: 0.7175
# Epoch 285/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0321 - categorical_accuracy: 0.9316 - val_loss: 0.2522 - val_categorical_accuracy: 0.7150
# Epoch 286/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0276 - categorical_accuracy: 0.9083 - val_loss: 0.2490 - val_categorical_accuracy: 0.7100
# Epoch 287/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0236 - categorical_accuracy: 0.9400 - val_loss: 0.2581 - val_categorical_accuracy: 0.7100
# Epoch 288/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0198 - categorical_accuracy: 0.9477 - val_loss: 0.2758 - val_categorical_accuracy: 0.7075
# Epoch 289/800
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0204 - categorical_accuracy: 0.9453 - val_loss: 0.3042 - val_categorical_accuracy: 0.7125
# Epoch 290/800
# ...
# Epoch 705/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0068 - categorical_accuracy: 0.9903 - val_loss: 0.3282 - val_categorical_accuracy: 0.7075
# Epoch 706/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0110 - categorical_accuracy: 0.9836 - val_loss: 0.3239 - val_categorical_accuracy: 0.7050
# Epoch 707/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0072 - categorical_accuracy: 0.9827 - val_loss: 0.3326 - val_categorical_accuracy: 0.7125
# Epoch 708/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0057 - categorical_accuracy: 0.9819 - val_loss: 0.3521 - val_categorical_accuracy: 0.7200
# Epoch 709/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0121 - categorical_accuracy: 0.9827 - val_loss: 0.3495 - val_categorical_accuracy: 0.7150
# Epoch 710/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0062 - categorical_accuracy: 0.9847 - val_loss: 0.3466 - val_categorical_accuracy: 0.7125
# Epoch 711/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0066 - categorical_accuracy: 0.9863 - val_loss: 0.3499 - val_categorical_accuracy: 0.7225
# Epoch 712/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0129 - categorical_accuracy: 0.9827 - val_loss: 0.3471 - val_categorical_accuracy: 0.7225
# Epoch 713/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0088 - categorical_accuracy: 0.9791 - val_loss: 0.3493 - val_categorical_accuracy: 0.7275
# Epoch 714/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0059 - categorical_accuracy: 0.9831 - val_loss: 0.3554 - val_categorical_accuracy: 0.7250
# Epoch 715/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0140 - categorical_accuracy: 0.9692 - val_loss: 0.3467 - val_categorical_accuracy: 0.7225
# Epoch 716/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0172 - categorical_accuracy: 0.9658 - val_loss: 0.3380 - val_categorical_accuracy: 0.7200
# Epoch 717/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0060 - categorical_accuracy: 0.9903 - val_loss: 0.3345 - val_categorical_accuracy: 0.7075
# Epoch 718/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0062 - categorical_accuracy: 0.9855 - val_loss: 0.3341 - val_categorical_accuracy: 0.7125
# Epoch 719/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0078 - categorical_accuracy: 0.9706 - val_loss: 0.3309 - val_categorical_accuracy: 0.7150
# Epoch 720/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0043 - categorical_accuracy: 0.9916 - val_loss: 0.3306 - val_categorical_accuracy: 0.7125
# Epoch 721/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0082 - categorical_accuracy: 0.9831 - val_loss: 0.3306 - val_categorical_accuracy: 0.7125
# Epoch 722/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0104 - categorical_accuracy: 0.9831 - val_loss: 0.3268 - val_categorical_accuracy: 0.7225
# Epoch 723/800
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0044 - categorical_accuracy: 0.9916 - val_loss: 0.3259 - val_categorical_accuracy: 0.7225
# Epoch 724/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0099 - categorical_accuracy: 0.9739 - val_loss: 0.3326 - val_categorical_accuracy: 0.7250
# Epoch 725/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0092 - categorical_accuracy: 0.9791 - val_loss: 0.3313 - val_categorical_accuracy: 0.7225
# Epoch 726/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0111 - categorical_accuracy: 0.9709 - val_loss: 0.3278 - val_categorical_accuracy: 0.7350
# Epoch 727/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0057 - categorical_accuracy: 0.9875 - val_loss: 0.3226 - val_categorical_accuracy: 0.7325
# Epoch 728/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0043 - categorical_accuracy: 0.9883 - val_loss: 0.3231 - val_categorical_accuracy: 0.7125
# Epoch 729/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0033 - categorical_accuracy: 0.9967 - val_loss: 0.3254 - val_categorical_accuracy: 0.7100
# Epoch 730/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0032 - categorical_accuracy: 0.9944 - val_loss: 0.3241 - val_categorical_accuracy: 0.7200
# Epoch 731/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0052 - categorical_accuracy: 0.9903 - val_loss: 0.3325 - val_categorical_accuracy: 0.7200
# Epoch 732/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0074 - categorical_accuracy: 0.9770 - val_loss: 0.3512 - val_categorical_accuracy: 0.7150
# Epoch 733/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0109 - categorical_accuracy: 0.9791 - val_loss: 0.3541 - val_categorical_accuracy: 0.7100
# Epoch 734/800
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0073 - categorical_accuracy: 0.9798 - val_loss: 0.3614 - val_categorical_accuracy: 0.7075
# Epoch 735/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0075 - categorical_accuracy: 0.9834 - val_loss: 0.3604 - val_categorical_accuracy: 0.7150
# Epoch 736/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0085 - categorical_accuracy: 0.9836 - val_loss: 0.3446 - val_categorical_accuracy: 0.7025
# Epoch 737/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0129 - categorical_accuracy: 0.9631 - val_loss: 0.3443 - val_categorical_accuracy: 0.7100
# Epoch 738/800
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0155 - categorical_accuracy: 0.9852 - val_loss: 0.3448 - val_categorical_accuracy: 0.7175
# Epoch 739/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0085 - categorical_accuracy: 0.9867 - val_loss: 0.3569 - val_categorical_accuracy: 0.7225
# Epoch 740/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0074 - categorical_accuracy: 0.9755 - val_loss: 0.3500 - val_categorical_accuracy: 0.7175
# Epoch 741/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0054 - categorical_accuracy: 0.9831 - val_loss: 0.3395 - val_categorical_accuracy: 0.7150
# Epoch 742/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0073 - categorical_accuracy: 0.9833 - val_loss: 0.3298 - val_categorical_accuracy: 0.7200
# Epoch 743/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0107 - categorical_accuracy: 0.9734 - val_loss: 0.3244 - val_categorical_accuracy: 0.7050
# Epoch 744/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0162 - categorical_accuracy: 0.9772 - val_loss: 0.3076 - val_categorical_accuracy: 0.7075
# Epoch 745/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0041 - categorical_accuracy: 0.9967 - val_loss: 0.3119 - val_categorical_accuracy: 0.7125
# Epoch 746/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0079 - categorical_accuracy: 0.9814 - val_loss: 0.3158 - val_categorical_accuracy: 0.7200
# Epoch 747/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0109 - categorical_accuracy: 0.9739 - val_loss: 0.3232 - val_categorical_accuracy: 0.7000
# Epoch 748/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0064 - categorical_accuracy: 0.9831 - val_loss: 0.3332 - val_categorical_accuracy: 0.7125
# Epoch 749/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0062 - categorical_accuracy: 0.9923 - val_loss: 0.3476 - val_categorical_accuracy: 0.7175
# Epoch 750/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0033 - categorical_accuracy: 0.9903 - val_loss: 0.3680 - val_categorical_accuracy: 0.7150
# Epoch 751/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0071 - categorical_accuracy: 0.9823 - val_loss: 0.3817 - val_categorical_accuracy: 0.7100
# Epoch 752/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0046 - categorical_accuracy: 0.9902 - val_loss: 0.3830 - val_categorical_accuracy: 0.7150
# Epoch 753/800
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0063 - categorical_accuracy: 0.9839 - val_loss: 0.3940 - val_categorical_accuracy: 0.7200
# Epoch 754/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0093 - categorical_accuracy: 0.9763 - val_loss: 0.3805 - val_categorical_accuracy: 0.7225
# Epoch 755/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0095 - categorical_accuracy: 0.9759 - val_loss: 0.3420 - val_categorical_accuracy: 0.7175
# Epoch 756/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0062 - categorical_accuracy: 0.9867 - val_loss: 0.3332 - val_categorical_accuracy: 0.7150
# Epoch 757/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0091 - categorical_accuracy: 0.9862 - val_loss: 0.3441 - val_categorical_accuracy: 0.7150
# Epoch 758/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0119 - categorical_accuracy: 0.9811 - val_loss: 0.3527 - val_categorical_accuracy: 0.7125
# Epoch 759/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0078 - categorical_accuracy: 0.9888 - val_loss: 0.3476 - val_categorical_accuracy: 0.7175
# Epoch 760/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0062 - categorical_accuracy: 0.9914 - val_loss: 0.3444 - val_categorical_accuracy: 0.7200
# Epoch 761/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0044 - categorical_accuracy: 0.9944 - val_loss: 0.3497 - val_categorical_accuracy: 0.7225
# Epoch 762/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0089 - categorical_accuracy: 0.9747 - val_loss: 0.3494 - val_categorical_accuracy: 0.7250
# Epoch 763/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0059 - categorical_accuracy: 0.9855 - val_loss: 0.3476 - val_categorical_accuracy: 0.7200
# Epoch 764/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0120 - categorical_accuracy: 0.9786 - val_loss: 0.3507 - val_categorical_accuracy: 0.7200
# Epoch 765/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0043 - categorical_accuracy: 0.9883 - val_loss: 0.3598 - val_categorical_accuracy: 0.7100
# Epoch 766/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0098 - categorical_accuracy: 0.9831 - val_loss: 0.3634 - val_categorical_accuracy: 0.7075
# Epoch 767/800
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0079 - categorical_accuracy: 0.9698 - val_loss: 0.3496 - val_categorical_accuracy: 0.7100
# Epoch 768/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0074 - categorical_accuracy: 0.9811 - val_loss: 0.3388 - val_categorical_accuracy: 0.7175
# Epoch 769/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0072 - categorical_accuracy: 0.9783 - val_loss: 0.3400 - val_categorical_accuracy: 0.7175
# Epoch 770/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0072 - categorical_accuracy: 0.9888 - val_loss: 0.3520 - val_categorical_accuracy: 0.7175
# Epoch 771/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0069 - categorical_accuracy: 0.9836 - val_loss: 0.3790 - val_categorical_accuracy: 0.7100
# Epoch 772/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0097 - categorical_accuracy: 0.9847 - val_loss: 0.3860 - val_categorical_accuracy: 0.7200
# Epoch 773/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0081 - categorical_accuracy: 0.9822 - val_loss: 0.3754 - val_categorical_accuracy: 0.7125
# Epoch 774/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0051 - categorical_accuracy: 0.9931 - val_loss: 0.3636 - val_categorical_accuracy: 0.7075
# Epoch 775/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0046 - categorical_accuracy: 0.9908 - val_loss: 0.3630 - val_categorical_accuracy: 0.7100
# Epoch 776/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0047 - categorical_accuracy: 0.9867 - val_loss: 0.3732 - val_categorical_accuracy: 0.7125
# Epoch 777/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0060 - categorical_accuracy: 0.9886 - val_loss: 0.3817 - val_categorical_accuracy: 0.7100
# Epoch 778/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0030 - categorical_accuracy: 0.9988 - val_loss: 0.3846 - val_categorical_accuracy: 0.7075
# Epoch 779/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0027 - categorical_accuracy: 0.9964 - val_loss: 0.3939 - val_categorical_accuracy: 0.7050
# Epoch 780/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0035 - categorical_accuracy: 0.9872 - val_loss: 0.4118 - val_categorical_accuracy: 0.7075
# Epoch 781/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0048 - categorical_accuracy: 0.9903 - val_loss: 0.4325 - val_categorical_accuracy: 0.7075
# Epoch 782/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0046 - categorical_accuracy: 0.9908 - val_loss: 0.4503 - val_categorical_accuracy: 0.6975
# Epoch 783/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0103 - categorical_accuracy: 0.9803 - val_loss: 0.4232 - val_categorical_accuracy: 0.7025
# Epoch 784/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0035 - categorical_accuracy: 0.9944 - val_loss: 0.4089 - val_categorical_accuracy: 0.7050
# Epoch 785/800
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0052 - categorical_accuracy: 0.9892 - val_loss: 0.3966 - val_categorical_accuracy: 0.7075
# Epoch 786/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0026 - categorical_accuracy: 0.9944 - val_loss: 0.3955 - val_categorical_accuracy: 0.7125
# Epoch 787/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0048 - categorical_accuracy: 0.9831 - val_loss: 0.4024 - val_categorical_accuracy: 0.7000
# Epoch 788/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0087 - categorical_accuracy: 0.9863 - val_loss: 0.3951 - val_categorical_accuracy: 0.7050
# Epoch 789/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0085 - categorical_accuracy: 0.9763 - val_loss: 0.4282 - val_categorical_accuracy: 0.7275
# Epoch 790/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0153 - categorical_accuracy: 0.9725 - val_loss: 0.4097 - val_categorical_accuracy: 0.7400
# Epoch 791/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0126 - categorical_accuracy: 0.9667 - val_loss: 0.3660 - val_categorical_accuracy: 0.7250
# Epoch 792/800
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0062 - categorical_accuracy: 0.9919 - val_loss: 0.3516 - val_categorical_accuracy: 0.7175
# Epoch 793/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0157 - categorical_accuracy: 0.9711 - val_loss: 0.3200 - val_categorical_accuracy: 0.7225
# Epoch 794/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0073 - categorical_accuracy: 0.9806 - val_loss: 0.3104 - val_categorical_accuracy: 0.7200
# Epoch 795/800
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0051 - categorical_accuracy: 0.9891 - val_loss: 0.3140 - val_categorical_accuracy: 0.7150
# Epoch 796/800
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0108 - categorical_accuracy: 0.9714 - val_loss: 0.3314 - val_categorical_accuracy: 0.7150
# Epoch 797/800
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0071 - categorical_accuracy: 0.9859 - val_loss: 0.3468 - val_categorical_accuracy: 0.7125
# Epoch 798/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0063 - categorical_accuracy: 0.9883 - val_loss: 0.3465 - val_categorical_accuracy: 0.7250
# Epoch 799/800
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0106 - categorical_accuracy: 0.9767 - val_loss: 0.3338 - val_categorical_accuracy: 0.7125
# Epoch 800/800
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0068 - categorical_accuracy: 0.9852 - val_loss: 0.3333 - val_categorical_accuracy: 0.7150

# %%
lg.normalize()

# %%
fig=px.scatter(lg.df, x="f1", y="f2", animation_frame="iterations", color="label",opacity=lg.df.arc,
                range_x=[-1.5,1.5],
              range_y=[-1.5,1.5])
fig.update_yaxes(
    scaleanchor = "x",
    scaleratio = 1,
)

# %%
fig.write_html("history/proto_matmult_tf.html")
